# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezafarhadi01/DrugDesignCourse-FinalProject/blob/main/DeepDTA_Version_2_(Wide_%2B_BN_%2B_Dropout_0_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Section 1

import json
import numpy as np
import pickle
import tensorflow as tf
from tensorflow.keras import layers, Model
from sklearn.metrics import mean_squared_error
import os
import warnings

warnings.filterwarnings('ignore')

# Install and import tqdm for progress bars
try:
    from tqdm import tqdm
except ImportError:
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "tqdm"])
    from tqdm import tqdm

# Basic optimizations
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['OMP_NUM_THREADS'] = str(os.cpu_count())

# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)

# Constants
KIBA_MAX_DRUG_LEN = 100
KIBA_MAX_PROT_LEN = 1000
EMBEDDING_DIM = 128
KIBA_DATA_PATH = './kiba'

# Enable XLA for faster computation
try:
    tf.config.optimizer.set_jit(True)
except:
    pass

def concordance_index(y_true, y_pred):
    """Optimized concordance index calculation."""
    y_true = y_true.flatten().astype(np.float32)
    y_pred = y_pred.flatten().astype(np.float32)

    # Remove NaN values
    mask = ~(np.isnan(y_true) | np.isnan(y_pred))
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    if len(y_true) < 2:
        return 0.0

    # For large datasets, use sampling for faster calculation
    if len(y_true) > 10000:
        indices = np.random.choice(len(y_true), 10000, replace=False)
        y_true = y_true[indices]
        y_pred = y_pred[indices]

    # Vectorized CI calculation
    n = len(y_true)
    indices = np.arange(n)
    i_indices, j_indices = np.meshgrid(indices, indices, indexing='ij')
    mask = i_indices < j_indices

    y_true_i = y_true[i_indices[mask]]
    y_true_j = y_true[j_indices[mask]]
    y_pred_i = y_pred[i_indices[mask]]
    y_pred_j = y_pred[j_indices[mask]]

    # Only consider pairs with different true values
    different_mask = y_true_i != y_true_j
    if np.sum(different_mask) == 0:
        return 0.0

    y_true_i = y_true_i[different_mask]
    y_true_j = y_true_j[different_mask]
    y_pred_i = y_pred_i[different_mask]
    y_pred_j = y_pred_j[different_mask]

    # Count concordant pairs
    concordant = ((y_true_i > y_true_j) & (y_pred_i > y_pred_j)) | \
                 ((y_true_i < y_true_j) & (y_pred_i < y_pred_j))
    ties = (y_pred_i == y_pred_j)

    return (np.sum(concordant) + 0.5 * np.sum(ties)) / len(y_true_i)

def create_char_vocab(sequences_dict):
    """Create character vocabulary with progress tracking."""
    char_set = set()

    # Use tqdm for vocabulary creation
    for seq in tqdm(sequences_dict.values(), desc="Processing sequences", unit="seq"):
        char_set.update(seq)

    chars = sorted(list(char_set))
    char_to_int = {char: idx + 1 for idx, char in enumerate(chars)}
    return char_to_int

def encode_sequences_batch(sequences, char_vocab, max_length, desc="Encoding sequences"):
    """Batch encode sequences with progress bar."""
    encoded_sequences = []

    for sequence in tqdm(sequences, desc=desc, unit="seq"):
        encoded = [char_vocab.get(char, 0) for char in sequence]
        if len(encoded) < max_length:
            encoded += [0] * (max_length - len(encoded))
        else:
            encoded = encoded[:max_length]
        encoded_sequences.append(encoded)

    return np.array(encoded_sequences, dtype=np.int32)

class OptimizedKibaDataProcessor:
    """Enhanced data processor with detailed progress tracking."""

    def __init__(self, data_path='./kiba', max_drug_len=100, max_prot_len=1000):
        self.data_path = data_path
        self.max_drug_len = max_drug_len
        self.max_prot_len = max_prot_len
        self.drug_vocab = None
        self.prot_vocab = None

    def load_data(self):
        """Load data with progress tracking."""

        try:
            # Load ligands and proteins
            ligands_path = os.path.join(self.data_path, 'ligands_can.txt')
            proteins_path = os.path.join(self.data_path, 'proteins.txt')

            with open(ligands_path, 'r') as f:
                drugs_dict = json.load(f)

            with open(proteins_path, 'r') as f:
                proteins_dict = json.load(f)

            # Load affinity matrix with progress indication
            y_file_path = os.path.join(self.data_path, 'Y')

            if os.path.exists(y_file_path):
                try:
                    with open(y_file_path, 'rb') as f:
                        affinity_matrix = pickle.load(f)
                except:
                    try:
                        with open(y_file_path, 'rb') as f:
                            affinity_matrix = pickle.load(f, encoding='latin1')
                    except Exception as e:
                        raise
            else:
                raise FileNotFoundError(f"Y file not found at {y_file_path}")

            # Find valid indices with progress
            valid_indices = np.where(~np.isnan(affinity_matrix))
            total_valid_pairs = len(valid_indices[0])

            # Create train/test split
            np.random.seed(42)
            all_indices = np.arange(total_valid_pairs)
            np.random.shuffle(all_indices)

            split_point = int(0.8 * total_valid_pairs)
            train_indices = all_indices[:split_point]
            test_indices = all_indices[split_point:]

            return drugs_dict, proteins_dict, affinity_matrix, train_indices, test_indices, valid_indices

        except Exception as e:
            return None

    def process_data(self):
        """Process data with comprehensive progress tracking."""
        data = self.load_data()
        if data is None:
            return None

        drugs_dict, proteins_dict, affinity_matrix, train_indices, test_indices, valid_indices = data

        self.drug_vocab = create_char_vocab(drugs_dict)
        self.prot_vocab = create_char_vocab(proteins_dict)

        drug_ids = list(drugs_dict.keys())
        protein_ids = list(proteins_dict.keys())

        def create_dataset_optimized(indices, dataset_name):
            """Create dataset with detailed progress tracking."""

            drug_sequences = []
            prot_sequences = []
            affinities = []

            chunk_size = 10000
            total_chunks = (len(indices) + chunk_size - 1) // chunk_size

            # Overall progress bar for chunks
            chunk_pbar = tqdm(total=total_chunks, desc=f"Processing {dataset_name} chunks", unit="chunk")

            for chunk_idx, i in enumerate(range(0, len(indices), chunk_size)):
                chunk_indices = indices[i:i + chunk_size]
                chunk_drugs = []
                chunk_prots = []
                chunk_affs = []

                # Progress bar for processing samples in this chunk
                sample_pbar = tqdm(
                    chunk_indices,
                    desc=f"Chunk {chunk_idx + 1}/{total_chunks}",
                    unit="sample",
                    leave=False
                )

                for idx in sample_pbar:
                    if idx < len(valid_indices[0]):
                        drug_idx = valid_indices[0][idx]
                        prot_idx = valid_indices[1][idx]

                        if drug_idx < len(drug_ids) and prot_idx < len(protein_ids):
                            drug_id = drug_ids[drug_idx]
                            prot_id = protein_ids[prot_idx]

                            chunk_drugs.append(drugs_dict[drug_id])
                            chunk_prots.append(proteins_dict[prot_id])
                            chunk_affs.append(affinity_matrix[drug_idx, prot_idx])

                sample_pbar.close()

                # Batch encode sequences with progress
                if chunk_drugs:
                    encoded_drugs = encode_sequences_batch(
                        chunk_drugs, self.drug_vocab, self.max_drug_len,
                        desc=f"Encoding drugs (chunk {chunk_idx + 1})"
                    )
                    encoded_prots = encode_sequences_batch(
                        chunk_prots, self.prot_vocab, self.max_prot_len,
                        desc=f"Encoding proteins (chunk {chunk_idx + 1})"
                    )

                    drug_sequences.append(encoded_drugs)
                    prot_sequences.append(encoded_prots)
                    affinities.extend(chunk_affs)

                chunk_pbar.update(1)

            chunk_pbar.close()

            # Concatenate all chunks with progress
            if drug_sequences:
                drugs = np.concatenate(drug_sequences, axis=0)
                proteins = np.concatenate(prot_sequences, axis=0)
                affinities = np.array(affinities, dtype=np.float32)
            else:
                drugs = np.array([], dtype=np.int32).reshape(0, self.max_drug_len)
                proteins = np.array([], dtype=np.int32).reshape(0, self.max_prot_len)
                affinities = np.array([], dtype=np.float32)

            return drugs, proteins, affinities

        XD_train, XT_train, y_train = create_dataset_optimized(train_indices, "training")
        XD_test, XT_test, y_test = create_dataset_optimized(test_indices, "test")

        return ((XD_train, XT_train, y_train),
                (XD_test, XT_test, y_test),
                (len(self.drug_vocab) + 1, len(self.prot_vocab) + 1))

def build_improved_deepdta_model(drug_vocab_size, prot_vocab_size, max_drug_len, max_prot_len):
    EMBEDDING_DIM = 128
    DROPOUT_RATE = 0.1
    LEARNING_RATE = 0.001

    # Wide CNN filters
    FILTER_NUM_1 = 64
    FILTER_NUM_2 = 128
    FILTER_NUM_3 = 192

    DRUG_FILTER_LENS = [4, 6, 8]
    PROT_FILTER_LENS = [4, 8, 12]

    FC_NEURONS_1 = 1024
    FC_NEURONS_2 = 1024
    FC_NEURONS_3 = 512

    # Drug branch
    drug_input = layers.Input(shape=(max_drug_len,), name='drug_input', dtype='int32')
    drug_embedding = layers.Embedding(
        input_dim=drug_vocab_size,
        output_dim=EMBEDDING_DIM,
        name='drug_embedding'
    )(drug_input)

    drug_conv1 = layers.Conv1D(FILTER_NUM_1, DRUG_FILTER_LENS[0], padding='valid')(drug_embedding)
    drug_bn1 = layers.BatchNormalization()(drug_conv1)
    drug_act1 = layers.Activation('relu')(drug_bn1)

    drug_conv2 = layers.Conv1D(FILTER_NUM_2, DRUG_FILTER_LENS[1], padding='valid')(drug_act1)
    drug_bn2 = layers.BatchNormalization()(drug_conv2)
    drug_act2 = layers.Activation('relu')(drug_bn2)

    drug_conv3 = layers.Conv1D(FILTER_NUM_3, DRUG_FILTER_LENS[2], padding='valid')(drug_act2)
    drug_bn3 = layers.BatchNormalization()(drug_conv3)
    drug_act3 = layers.Activation('relu')(drug_bn3)

    drug_pool = layers.GlobalMaxPooling1D()(drug_act3)

    # Protein branch
    prot_input = layers.Input(shape=(max_prot_len,), name='protein_input', dtype='int32')
    prot_embedding = layers.Embedding(
        input_dim=prot_vocab_size,
        output_dim=EMBEDDING_DIM,
        name='protein_embedding'
    )(prot_input)

    prot_conv1 = layers.Conv1D(FILTER_NUM_1, PROT_FILTER_LENS[0], padding='valid')(prot_embedding)
    prot_bn1 = layers.BatchNormalization()(prot_conv1)
    prot_act1 = layers.Activation('relu')(prot_bn1)

    prot_conv2 = layers.Conv1D(FILTER_NUM_2, PROT_FILTER_LENS[1], padding='valid')(prot_act1)
    prot_bn2 = layers.BatchNormalization()(prot_conv2)
    prot_act2 = layers.Activation('relu')(prot_bn2)

    prot_conv3 = layers.Conv1D(FILTER_NUM_3, PROT_FILTER_LENS[2], padding='valid')(prot_act2)
    prot_bn3 = layers.BatchNormalization()(prot_conv3)
    prot_act3 = layers.Activation('relu')(prot_bn3)

    prot_pool = layers.GlobalMaxPooling1D()(prot_act3)

    # Merge branches
    combined = layers.Concatenate()([drug_pool, prot_pool])

    fc1 = layers.Dense(FC_NEURONS_1, activation='relu')(combined)
    fc1 = layers.Dropout(DROPOUT_RATE)(fc1)

    fc2 = layers.Dense(FC_NEURONS_2, activation='relu')(fc1)
    fc2 = layers.Dropout(DROPOUT_RATE)(fc2)

    fc3 = layers.Dense(FC_NEURONS_3, activation='relu')(fc2)

    output = layers.Dense(1, activation='linear')(fc3)

    model = Model(inputs=[drug_input, prot_input], outputs=output)

    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])

    return model



print("All functions and classes defined successfully!")
print("OptimizedKibaDataProcessor is now available!")
print("Ready to process data!")
# Out:
# All functions and classes defined successfully!
# OptimizedKibaDataProcessor is now available!
# Ready to process data!

# %%
#Section 2

import zipfile
import os

# Define the path to your zip file
zip_file_path = '/content/data.zip' # Replace with the actual path to your .zip file

# Define the directory where you want to extract the contents
# If the directory doesn't exist, it will be created.
extract_dir = '/content/' # You can change this to your desired extraction path

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Extract the zip file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"Successfully extracted '{zip_file_path}' to '{extract_dir}'")
except FileNotFoundError:
    print(f"Error: The file '{zip_file_path}' was not found.")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Optional: List the contents of the extracted directory to verify
print("\nContents of the extracted directory:")
for item in os.listdir(extract_dir):
    print(os.path.join(extract_dir, item))
# Out:
# Successfully extracted '/content/data.zip' to '/content/'
#
# Contents of the extracted directory:
# /content/.config
# /content/davis
# /content/data.zip
# /content/kiba
# /content/sample_data

# %%
#Section 3

# Process the data
print("=== Starting Data Processing ===")

# Check if data path exists
if not os.path.exists(KIBA_DATA_PATH):
    print(f"Data path not found: {KIBA_DATA_PATH}")
    print("Please make sure you have uploaded and extracted the kiba folder.")
    print("Current directory contents:")
    for item in os.listdir('.'):
        print(f"  - {item}")
else:
    print(f"Data path found: {KIBA_DATA_PATH}")

    # Now OptimizedKibaDataProcessor should be available
    processor = OptimizedKibaDataProcessor(data_path=KIBA_DATA_PATH)

    processed_data = processor.process_data()
    if processed_data is None:
        print("Failed to process data. Please check your data files.")
    else:
        (XD_train, XT_train, y_train), (XD_test, XT_test, y_test), (drug_vocab_size, prot_vocab_size) = processed_data
        print("Data processing completed successfully!")
        print(f"Data shapes:")
        print(f"   XD_train: {XD_train.shape}, dtype: {XD_train.dtype}")
        print(f"   XT_train: {XT_train.shape}, dtype: {XT_train.dtype}")
        print(f"   y_train: {y_train.shape}, dtype: {y_train.dtype}")
        print(f"   XD_test: {XD_test.shape}, dtype: {XD_test.dtype}")
        print(f"   XT_test: {XT_test.shape}, dtype: {XT_test.dtype}")
        print(f"   y_test: {y_test.shape}, dtype: {y_test.dtype}")
# Out:
# === Starting Data Processing ===
# Data path found: ./kiba
# Processing sequences: 100%|██████████| 2111/2111 [00:00<00:00, 710095.10seq/s]
# Processing sequences: 100%|██████████| 229/229 [00:00<00:00, 46981.79seq/s]
# Processing training chunks:   0%|          | 0/10 [00:00<?, ?chunk/s]
# Chunk 1/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 120558.20seq/s]
#
# Encoding proteins (chunk 1):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 1):  13%|█▎        | 1349/10000 [00:00<00:00, 13480.60seq/s]
# Encoding proteins (chunk 1):  27%|██▋       | 2698/10000 [00:00<00:00, 12974.83seq/s]
# Encoding proteins (chunk 1):  40%|███▉      | 3997/10000 [00:00<00:00, 12481.56seq/s]
# Encoding proteins (chunk 1):  52%|█████▏    | 5248/10000 [00:00<00:00, 12417.93seq/s]
# Encoding proteins (chunk 1):  65%|██████▍   | 6491/10000 [00:00<00:00, 10913.05seq/s]
# Encoding proteins (chunk 1):  77%|███████▋  | 7697/10000 [00:00<00:00, 11262.36seq/s]
# Encoding proteins (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 11667.27seq/s]
# Processing training chunks:  10%|█         | 1/10 [00:01<00:13,  1.53s/chunk]
# Chunk 2/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 239539.00seq/s]
#
# Encoding proteins (chunk 2):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 2):  23%|██▎       | 2298/10000 [00:00<00:00, 22971.97seq/s]
# Encoding proteins (chunk 2):  46%|████▌     | 4596/10000 [00:00<00:00, 20925.46seq/s]
# Encoding proteins (chunk 2):  67%|██████▋   | 6701/10000 [00:00<00:00, 20151.13seq/s]
# Encoding proteins (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 20709.76seq/s]
# Processing training chunks:  20%|██        | 2/10 [00:02<00:09,  1.19s/chunk]
# Chunk 3/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 3): 100%|██████████| 10000/10000 [00:00<00:00, 244364.92seq/s]
#
# Encoding proteins (chunk 3):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 3):  23%|██▎       | 2292/10000 [00:00<00:00, 22914.78seq/s]
# Encoding proteins (chunk 3):  46%|████▌     | 4584/10000 [00:00<00:00, 22186.13seq/s]
# Encoding proteins (chunk 3):  68%|██████▊   | 6805/10000 [00:00<00:00, 21679.84seq/s]
# Encoding proteins (chunk 3): 100%|██████████| 10000/10000 [00:00<00:00, 19694.27seq/s]
# Processing training chunks:  30%|███       | 3/10 [00:03<00:07,  1.10s/chunk]
# Chunk 4/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 4):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding drugs (chunk 4): 100%|██████████| 10000/10000 [00:00<00:00, 45719.37seq/s]
#
# Encoding proteins (chunk 4):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 4):  23%|██▎       | 2272/10000 [00:00<00:00, 22718.99seq/s]
# Encoding proteins (chunk 4):  45%|████▌     | 4544/10000 [00:00<00:00, 22100.54seq/s]
# Encoding proteins (chunk 4):  68%|██████▊   | 6756/10000 [00:00<00:00, 20898.06seq/s]
# Encoding proteins (chunk 4): 100%|██████████| 10000/10000 [00:00<00:00, 19923.35seq/s]
# Processing training chunks:  40%|████      | 4/10 [00:04<00:06,  1.12s/chunk]
# Chunk 5/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 5): 100%|██████████| 10000/10000 [00:00<00:00, 243101.55seq/s]
#
# Encoding proteins (chunk 5):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 5):  22%|██▏       | 2243/10000 [00:00<00:00, 22429.38seq/s]
# Encoding proteins (chunk 5):  45%|████▍     | 4486/10000 [00:00<00:00, 20372.40seq/s]
# Encoding proteins (chunk 5):  65%|██████▌   | 6536/10000 [00:00<00:00, 19905.20seq/s]
# Encoding proteins (chunk 5): 100%|██████████| 10000/10000 [00:00<00:00, 20655.23seq/s]
# Processing training chunks:  50%|█████     | 5/10 [00:05<00:05,  1.06s/chunk]
# Chunk 6/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 6): 100%|██████████| 10000/10000 [00:00<00:00, 227203.02seq/s]
#
# Encoding proteins (chunk 6):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 6):  22%|██▏       | 2210/10000 [00:00<00:00, 22097.18seq/s]
# Encoding proteins (chunk 6):  44%|████▍     | 4420/10000 [00:00<00:00, 21546.96seq/s]
# Encoding proteins (chunk 6):  66%|██████▌   | 6576/10000 [00:00<00:00, 20536.50seq/s]
# Encoding proteins (chunk 6): 100%|██████████| 10000/10000 [00:00<00:00, 19352.35seq/s]
# Processing training chunks:  60%|██████    | 6/10 [00:06<00:04,  1.04s/chunk]
# Chunk 7/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 7): 100%|██████████| 10000/10000 [00:00<00:00, 225700.43seq/s]
#
# Encoding proteins (chunk 7):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 7):  22%|██▏       | 2237/10000 [00:00<00:00, 22368.69seq/s]
# Encoding proteins (chunk 7):  45%|████▍     | 4474/10000 [00:00<00:00, 21829.53seq/s]
# Encoding proteins (chunk 7):  67%|██████▋   | 6672/10000 [00:00<00:00, 21891.57seq/s]
# Encoding proteins (chunk 7): 100%|██████████| 10000/10000 [00:00<00:00, 20037.27seq/s]
# Processing training chunks:  70%|███████   | 7/10 [00:07<00:03,  1.01s/chunk]
# Chunk 8/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 8): 100%|██████████| 10000/10000 [00:00<00:00, 231922.99seq/s]
#
# Encoding proteins (chunk 8):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 8):  23%|██▎       | 2271/10000 [00:00<00:00, 22707.86seq/s]
# Encoding proteins (chunk 8):  45%|████▌     | 4542/10000 [00:00<00:00, 20347.12seq/s]
# Encoding proteins (chunk 8):  67%|██████▋   | 6732/10000 [00:00<00:00, 21012.18seq/s]
# Encoding proteins (chunk 8): 100%|██████████| 10000/10000 [00:00<00:00, 20558.42seq/s]
# Processing training chunks:  80%|████████  | 8/10 [00:08<00:01,  1.00chunk/s]
# Chunk 9/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 9): 100%|██████████| 10000/10000 [00:00<00:00, 234118.55seq/s]
#
# Encoding proteins (chunk 9):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 9):  21%|██        | 2108/10000 [00:00<00:00, 21070.48seq/s]
# Encoding proteins (chunk 9):  42%|████▏     | 4216/10000 [00:00<00:00, 20558.72seq/s]
# Encoding proteins (chunk 9):  63%|██████▎   | 6344/10000 [00:00<00:00, 20883.25seq/s]
# Encoding proteins (chunk 9): 100%|██████████| 10000/10000 [00:00<00:00, 19696.82seq/s]
# Processing training chunks:  90%|█████████ | 9/10 [00:09<00:00,  1.00chunk/s]
# Chunk 10/10:   0%|          | 0/4603 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 10): 100%|██████████| 4603/4603 [00:00<00:00, 224646.92seq/s]
#
# Encoding proteins (chunk 10):   0%|          | 0/4603 [00:00<?, ?seq/s]
# Encoding proteins (chunk 10):  49%|████▉     | 2274/4603 [00:00<00:00, 22738.88seq/s]
# Encoding proteins (chunk 10): 100%|██████████| 4603/4603 [00:00<00:00, 20385.01seq/s]
# Processing training chunks: 100%|██████████| 10/10 [00:09<00:00,  1.00chunk/s]
# Processing test chunks:   0%|          | 0/3 [00:00<?, ?chunk/s]
# Chunk 1/3:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 178220.89seq/s]
#
# Encoding proteins (chunk 1):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 1):  21%|██▏       | 2149/10000 [00:00<00:00, 21318.18seq/s]
# Encoding proteins (chunk 1):  43%|████▎     | 4281/10000 [00:00<00:00, 21183.87seq/s]
# Encoding proteins (chunk 1):  65%|██████▍   | 6454/10000 [00:00<00:00, 21429.88seq/s]
# Encoding proteins (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 20124.79seq/s]
# Processing test chunks:  33%|███▎      | 1/3 [00:00<00:01,  1.04chunk/s]
# Chunk 2/3:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 234229.68seq/s]
#
# Encoding proteins (chunk 2):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 2):  14%|█▍        | 1391/10000 [00:00<00:00, 13906.37seq/s]
# Encoding proteins (chunk 2):  28%|██▊       | 2782/10000 [00:00<00:00, 13043.97seq/s]
# Encoding proteins (chunk 2):  41%|████      | 4090/10000 [00:00<00:00, 13005.87seq/s]
# Encoding proteins (chunk 2):  54%|█████▍    | 5393/10000 [00:00<00:00, 11930.82seq/s]
# Encoding proteins (chunk 2):  66%|██████▌   | 6617/10000 [00:00<00:00, 12032.66seq/s]
# Encoding proteins (chunk 2):  79%|███████▊  | 7869/10000 [00:00<00:00, 12188.96seq/s]
# Encoding proteins (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 11903.82seq/s]
# Processing test chunks:  67%|██████▋   | 2/3 [00:02<00:01,  1.39s/chunk]
# Chunk 3/3:   0%|          | 0/3651 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 3): 100%|██████████| 3651/3651 [00:00<00:00, 127789.54seq/s]
#
# Encoding proteins (chunk 3):   0%|          | 0/3651 [00:00<?, ?seq/s]
# Encoding proteins (chunk 3):  38%|███▊      | 1375/3651 [00:00<00:00, 13747.39seq/s]
# Encoding proteins (chunk 3): 100%|██████████| 3651/3651 [00:00<00:00, 12890.97seq/s]
# Processing test chunks: 100%|██████████| 3/3 [00:03<00:00,  1.09s/chunk]
# Data processing completed successfully!
# Data shapes:
#    XD_train: (94603, 100), dtype: int32
#    XT_train: (94603, 1000), dtype: int32
#    y_train: (94603,), dtype: float32
#    XD_test: (23651, 100), dtype: int32
#    XT_test: (23651, 1000), dtype: int32
#    y_test: (23651,), dtype: float32

# %%
#Section 4

# CORRECTED CONFIGURATION FOR TRUE 75% DATASET
REDUCE_DATASET = True
DATASET_FRACTION = 0.75
EPOCHS = 100
BATCH_SIZE = 256  # REDUCED for better stability
VALIDATION_SPLIT = 0.1

print("CORRECTED CONFIGURATION FOR 75% DATASET:")
print("=" * 50)
print(f"Dataset fraction: {DATASET_FRACTION*100}%")
print(f"Batch size: {BATCH_SIZE}")
print(f"Epochs: {EPOCHS}")

# FIXED: Proper dataset reduction
if 'XD_train' in locals() and len(XD_train) > 1000:  # Only if we have full data

    # Use the ORIGINAL full dataset, not the already reduced one
    print(f"Using original dataset: {len(XD_train):,} training samples")

    # Calculate correct sample sizes
    n_train = int(len(XD_train) * DATASET_FRACTION)
    n_test = int(len(XD_test) * DATASET_FRACTION)

    print(f"Target training samples: {n_train:,}")
    print(f"Target test samples: {n_test:,}")

    # Randomly sample subset
    np.random.seed(42)  # For reproducibility
    train_indices = np.random.choice(len(XD_train), n_train, replace=False)
    test_indices = np.random.choice(len(XD_test), n_test, replace=False)

    XD_train_75 = XD_train[train_indices]
    XT_train_75 = XT_train[train_indices]
    y_train_75 = y_train[train_indices]

    XD_test_75 = XD_test[test_indices]
    XT_test_75 = XT_test[test_indices]
    y_test_75 = y_test[test_indices]

    # Calculate batches per epoch
    batches_per_epoch = len(XD_train_75) // BATCH_SIZE

    print(f"CORRECTED DATASET:")
    print(f"   Training: {len(XD_train_75):,} samples")
    print(f"   Test: {len(XD_test_75):,} samples")
    print(f"   Batches per epoch: {batches_per_epoch}")
    print(f"   Much more stable training expected!")

    # Use corrected datasets
    XD_train = XD_train_75
    XT_train = XT_train_75
    y_train = y_train_75
    XD_test = XD_test_75
    XT_test = XT_test_75
    y_test = y_test_75

    print("Ready for corrected training!")

elif 'XD_train' in locals():
    print(f"Current dataset already reduced: {len(XD_train):,} samples")
    print("Please restart and run data processing again for full dataset")

    # Still apply batch size fix for current data
    batches_per_epoch = len(XD_train) // BATCH_SIZE
    print(f"Batches per epoch with current data: {batches_per_epoch}")

else:
    print("Cannot apply optimizations - data not loaded yet!")
# Out:
# CORRECTED CONFIGURATION FOR 75% DATASET:
# ==================================================
# Dataset fraction: 75.0%
# Batch size: 256
# Epochs: 100
# Using original dataset: 94,603 training samples
# Target training samples: 70,952
# Target test samples: 17,738
# CORRECTED DATASET:
#    Training: 70,952 samples
#    Test: 17,738 samples
#    Batches per epoch: 277
#    Much more stable training expected!
# Ready for corrected training!

# %%
#Section 5

# Build the model (only if data processing was successful)
if 'XD_train' in locals() and 'drug_vocab_size' in locals():
    print("\n=== Building Optimized Model ===")

    # Build the fast model
    fast_model = build_fast_deepdta_model(
        drug_vocab_size=drug_vocab_size,
        prot_vocab_size=prot_vocab_size,
        max_drug_len=processor.max_drug_len,
        max_prot_len=processor.max_prot_len
    )

    print("\n=== Model Summary ===")
    fast_model.summary()
    print("Model built successfully!")
else:
    print("Cannot build model - data processing failed or incomplete")
# Out:
# === Building Optimized Model ===
#
# === Model Summary ===
# Model: "DeepDTA"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ drug_input          │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_input       │ (None, 1000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_embedding      │ (None, 100, 128)  │      3,840 │ drug_input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_embedding   │ (None, 1000, 128) │      2,688 │ protein_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_conv1 (Conv1D) │ (None, 97, 32)    │     16,416 │ drug_embedding[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_conv1       │ (None, 997, 32)   │     16,416 │ protein_embeddin… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_conv2 (Conv1D) │ (None, 92, 64)    │     12,352 │ drug_conv1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_conv2       │ (None, 990, 64)   │     16,448 │ protein_conv1[0]… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_conv3 (Conv1D) │ (None, 85, 96)    │     49,248 │ drug_conv2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_conv3       │ (None, 979, 96)   │     73,824 │ protein_conv2[0]… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_global_max_po… │ (None, 96)        │          0 │ drug_conv3[0][0]  │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_global_max… │ (None, 96)        │          0 │ protein_conv3[0]… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_branch… │ (None, 192)       │          0 │ drug_global_max_… │
# │ (Concatenate)       │                   │            │ protein_global_m… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_1   │ (None, 1024)      │    197,632 │ concatenate_bran… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ fully_connected_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_2   │ (None, 1024)      │  1,049,600 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1024)      │          0 │ fully_connected_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_3   │ (None, 512)       │    524,800 │ dropout_2[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │        513 │ fully_connected_… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,963,777 (7.49 MB)
#  Trainable params: 1,963,777 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Model built successfully!

# %%
#Section 6

# OPTIMIZED TRAINING FOR 75% DATASET
if 'fast_model' in locals():
    print("STARTING OPTIMIZED TRAINING FOR 75% DATASET...")
    print("=" * 55)

    # Training configuration summary
    print(f"Configuration Summary:")
    print(f"   Dataset size: {DATASET_FRACTION*100}%")
    print(f"   Batch size: {BATCH_SIZE}")
    print(f"   Epochs: {EPOCHS}")
    print(f"   Training samples: {len(XD_train):,}")
    print(f"   Test samples: {len(XD_test):,}")
    print(f"   Batches per epoch: {len(XD_train) // BATCH_SIZE}")

    # Optimized callbacks for 75% dataset
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=15,  # More patience for larger dataset
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=7,   # More patience for larger dataset
            min_lr=1e-6,
            verbose=1
        )
    ]

    print(f"\nStarting training...")
    print(f"Expected CI: 0.72-0.78 (significant improvement over 50%)")
    print(f"Expected total time: 1-3 minutes")
    print("=" * 55)

    import time
    start_time = time.time()

    # Train the model
    history = fast_model.fit(
        x=[XD_train, XT_train],
        y=y_train,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        validation_split=VALIDATION_SPLIT,
        callbacks=callbacks,
        verbose=1
    )

    end_time = time.time()
    training_time = end_time - start_time

    print(f"\nTRAINING COMPLETED!")
    print("=" * 30)
    print(f"Total training time: {training_time/60:.1f} minutes")
    print(f"Average per epoch: {training_time/len(history.history['loss']):.1f} seconds")
    print(f"Best validation loss: {min(history.history['val_loss']):.4f}")
    print(f"Final training loss: {history.history['loss'][-1]:.4f}")
    print(f"Total epochs completed: {len(history.history['loss'])}")

else:
    print("Cannot start training - model not built")
# Out:
# STARTING OPTIMIZED TRAINING FOR 75% DATASET...
# =======================================================
# Configuration Summary:
#    Dataset size: 75.0%
#    Batch size: 256
#    Epochs: 100
#    Training samples: 70,952
#    Test samples: 17,738
#    Batches per epoch: 277
#
# Starting training...
# Expected CI: 0.72-0.78 (significant improvement over 50%)
# Expected total time: 1-3 minutes
# =======================================================
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 63s 197ms/step - loss: 12.0620 - mean_squared_error: 12.0620 - val_loss: 0.5359 - val_mean_squared_error: 0.5359 - learning_rate: 0.0010
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 65s 167ms/step - loss: 0.6489 - mean_squared_error: 0.6489 - val_loss: 0.4945 - val_mean_squared_error: 0.4945 - learning_rate: 0.0010
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 168ms/step - loss: 0.6238 - mean_squared_error: 0.6238 - val_loss: 0.5071 - val_mean_squared_error: 0.5071 - learning_rate: 0.0010
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.5560 - mean_squared_error: 0.5560 - val_loss: 0.5378 - val_mean_squared_error: 0.5378 - learning_rate: 0.0010
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.5418 - mean_squared_error: 0.5418 - val_loss: 0.5586 - val_mean_squared_error: 0.5586 - learning_rate: 0.0010
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.5573 - mean_squared_error: 0.5573 - val_loss: 0.7110 - val_mean_squared_error: 0.7110 - learning_rate: 0.0010
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.5236 - mean_squared_error: 0.5236 - val_loss: 0.3947 - val_mean_squared_error: 0.3947 - learning_rate: 0.0010
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.4980 - mean_squared_error: 0.4980 - val_loss: 0.5352 - val_mean_squared_error: 0.5352 - learning_rate: 0.0010
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.4895 - mean_squared_error: 0.4895 - val_loss: 0.6772 - val_mean_squared_error: 0.6772 - learning_rate: 0.0010
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.4947 - mean_squared_error: 0.4947 - val_loss: 0.4915 - val_mean_squared_error: 0.4915 - learning_rate: 0.0010
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.4699 - mean_squared_error: 0.4699 - val_loss: 0.3637 - val_mean_squared_error: 0.3637 - learning_rate: 0.0010
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.4379 - mean_squared_error: 0.4379 - val_loss: 0.3975 - val_mean_squared_error: 0.3975 - learning_rate: 0.0010
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.4215 - mean_squared_error: 0.4215 - val_loss: 0.3429 - val_mean_squared_error: 0.3429 - learning_rate: 0.0010
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.3997 - mean_squared_error: 0.3997 - val_loss: 0.3431 - val_mean_squared_error: 0.3431 - learning_rate: 0.0010
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.4027 - mean_squared_error: 0.4027 - val_loss: 0.4726 - val_mean_squared_error: 0.4726 - learning_rate: 0.0010
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.3874 - mean_squared_error: 0.3874 - val_loss: 0.3327 - val_mean_squared_error: 0.3327 - learning_rate: 0.0010
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.3599 - mean_squared_error: 0.3599 - val_loss: 0.3683 - val_mean_squared_error: 0.3683 - learning_rate: 0.0010
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.3492 - mean_squared_error: 0.3492 - val_loss: 0.3272 - val_mean_squared_error: 0.3272 - learning_rate: 0.0010
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.3354 - mean_squared_error: 0.3354 - val_loss: 0.3110 - val_mean_squared_error: 0.3110 - learning_rate: 0.0010
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.3278 - mean_squared_error: 0.3278 - val_loss: 0.2929 - val_mean_squared_error: 0.2929 - learning_rate: 0.0010
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.3198 - mean_squared_error: 0.3198 - val_loss: 0.3097 - val_mean_squared_error: 0.3097 - learning_rate: 0.0010
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.3068 - mean_squared_error: 0.3068 - val_loss: 0.2894 - val_mean_squared_error: 0.2894 - learning_rate: 0.0010
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.3101 - mean_squared_error: 0.3101 - val_loss: 0.2832 - val_mean_squared_error: 0.2832 - learning_rate: 0.0010
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.3002 - mean_squared_error: 0.3002 - val_loss: 0.2853 - val_mean_squared_error: 0.2853 - learning_rate: 0.0010
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.3024 - mean_squared_error: 0.3024 - val_loss: 0.2736 - val_mean_squared_error: 0.2736 - learning_rate: 0.0010
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.2780 - mean_squared_error: 0.2780 - val_loss: 0.2930 - val_mean_squared_error: 0.2930 - learning_rate: 0.0010
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.2806 - mean_squared_error: 0.2806 - val_loss: 0.2794 - val_mean_squared_error: 0.2794 - learning_rate: 0.0010
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.2647 - mean_squared_error: 0.2647 - val_loss: 0.2735 - val_mean_squared_error: 0.2735 - learning_rate: 0.0010
# Epoch 29/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.2573 - mean_squared_error: 0.2573 - val_loss: 0.2844 - val_mean_squared_error: 0.2844 - learning_rate: 0.0010
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.2507 - mean_squared_error: 0.2507 - val_loss: 0.2596 - val_mean_squared_error: 0.2596 - learning_rate: 0.0010
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.2449 - mean_squared_error: 0.2449 - val_loss: 0.2578 - val_mean_squared_error: 0.2578 - learning_rate: 0.0010
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.2400 - mean_squared_error: 0.2400 - val_loss: 0.2684 - val_mean_squared_error: 0.2684 - learning_rate: 0.0010
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.2280 - mean_squared_error: 0.2280 - val_loss: 0.2757 - val_mean_squared_error: 0.2757 - learning_rate: 0.0010
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.2262 - mean_squared_error: 0.2262 - val_loss: 0.3140 - val_mean_squared_error: 0.3140 - learning_rate: 0.0010
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.2250 - mean_squared_error: 0.2250 - val_loss: 0.2676 - val_mean_squared_error: 0.2676 - learning_rate: 0.0010
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.2231 - mean_squared_error: 0.2231 - val_loss: 0.2481 - val_mean_squared_error: 0.2481 - learning_rate: 0.0010
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 170ms/step - loss: 0.2153 - mean_squared_error: 0.2153 - val_loss: 0.2412 - val_mean_squared_error: 0.2412 - learning_rate: 0.0010
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1961 - mean_squared_error: 0.1961 - val_loss: 0.2537 - val_mean_squared_error: 0.2537 - learning_rate: 0.0010
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.1877 - mean_squared_error: 0.1877 - val_loss: 0.2523 - val_mean_squared_error: 0.2523 - learning_rate: 0.0010
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1983 - mean_squared_error: 0.1983 - val_loss: 0.2468 - val_mean_squared_error: 0.2468 - learning_rate: 0.0010
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1879 - mean_squared_error: 0.1879 - val_loss: 0.2440 - val_mean_squared_error: 0.2440 - learning_rate: 0.0010
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.1770 - mean_squared_error: 0.1770 - val_loss: 0.2390 - val_mean_squared_error: 0.2390 - learning_rate: 0.0010
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 171ms/step - loss: 0.1691 - mean_squared_error: 0.1691 - val_loss: 0.2404 - val_mean_squared_error: 0.2404 - learning_rate: 0.0010
# Epoch 44/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1668 - mean_squared_error: 0.1668 - val_loss: 0.2393 - val_mean_squared_error: 0.2393 - learning_rate: 0.0010
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1640 - mean_squared_error: 0.1640 - val_loss: 0.2452 - val_mean_squared_error: 0.2452 - learning_rate: 0.0010
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1621 - mean_squared_error: 0.1621 - val_loss: 0.2409 - val_mean_squared_error: 0.2409 - learning_rate: 0.0010
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1669 - mean_squared_error: 0.1669 - val_loss: 0.2403 - val_mean_squared_error: 0.2403 - learning_rate: 0.0010
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1758 - mean_squared_error: 0.1758 - val_loss: 0.2408 - val_mean_squared_error: 0.2408 - learning_rate: 0.0010
# Epoch 49/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.1656 - mean_squared_error: 0.1656
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.1655 - mean_squared_error: 0.1655 - val_loss: 0.2398 - val_mean_squared_error: 0.2398 - learning_rate: 0.0010
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 170ms/step - loss: 0.1322 - mean_squared_error: 0.1322 - val_loss: 0.2226 - val_mean_squared_error: 0.2226 - learning_rate: 5.0000e-04
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.1142 - mean_squared_error: 0.1142 - val_loss: 0.2220 - val_mean_squared_error: 0.2220 - learning_rate: 5.0000e-04
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.1037 - mean_squared_error: 0.1037 - val_loss: 0.2243 - val_mean_squared_error: 0.2243 - learning_rate: 5.0000e-04
# Epoch 53/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0963 - mean_squared_error: 0.0963 - val_loss: 0.2187 - val_mean_squared_error: 0.2187 - learning_rate: 5.0000e-04
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0918 - mean_squared_error: 0.0918 - val_loss: 0.2232 - val_mean_squared_error: 0.2232 - learning_rate: 5.0000e-04
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0880 - mean_squared_error: 0.0880 - val_loss: 0.2403 - val_mean_squared_error: 0.2403 - learning_rate: 5.0000e-04
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0876 - mean_squared_error: 0.0876 - val_loss: 0.2395 - val_mean_squared_error: 0.2395 - learning_rate: 5.0000e-04
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0848 - mean_squared_error: 0.0848 - val_loss: 0.2411 - val_mean_squared_error: 0.2411 - learning_rate: 5.0000e-04
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0828 - mean_squared_error: 0.0828 - val_loss: 0.2162 - val_mean_squared_error: 0.2162 - learning_rate: 5.0000e-04
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 171ms/step - loss: 0.0782 - mean_squared_error: 0.0782 - val_loss: 0.2185 - val_mean_squared_error: 0.2185 - learning_rate: 5.0000e-04
# Epoch 60/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0774 - mean_squared_error: 0.0774 - val_loss: 0.2131 - val_mean_squared_error: 0.2131 - learning_rate: 5.0000e-04
# Epoch 61/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0751 - mean_squared_error: 0.0751 - val_loss: 0.2336 - val_mean_squared_error: 0.2336 - learning_rate: 5.0000e-04
# Epoch 62/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0802 - mean_squared_error: 0.0802 - val_loss: 0.2225 - val_mean_squared_error: 0.2225 - learning_rate: 5.0000e-04
# Epoch 63/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0862 - mean_squared_error: 0.0862 - val_loss: 0.2158 - val_mean_squared_error: 0.2158 - learning_rate: 5.0000e-04
# Epoch 64/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0823 - mean_squared_error: 0.0823 - val_loss: 0.2530 - val_mean_squared_error: 0.2530 - learning_rate: 5.0000e-04
# Epoch 65/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0827 - mean_squared_error: 0.0827 - val_loss: 0.2099 - val_mean_squared_error: 0.2099 - learning_rate: 5.0000e-04
# Epoch 66/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0737 - mean_squared_error: 0.0737 - val_loss: 0.2557 - val_mean_squared_error: 0.2557 - learning_rate: 5.0000e-04
# Epoch 67/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.2777 - val_mean_squared_error: 0.2777 - learning_rate: 5.0000e-04
# Epoch 68/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0901 - mean_squared_error: 0.0901 - val_loss: 0.2126 - val_mean_squared_error: 0.2126 - learning_rate: 5.0000e-04
# Epoch 69/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0835 - mean_squared_error: 0.0835 - val_loss: 0.2120 - val_mean_squared_error: 0.2120 - learning_rate: 5.0000e-04
# Epoch 70/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0745 - mean_squared_error: 0.0745 - val_loss: 0.2097 - val_mean_squared_error: 0.2097 - learning_rate: 5.0000e-04
# Epoch 71/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0621 - mean_squared_error: 0.0621 - val_loss: 0.2141 - val_mean_squared_error: 0.2141 - learning_rate: 5.0000e-04
# Epoch 72/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0592 - mean_squared_error: 0.0592 - val_loss: 0.2199 - val_mean_squared_error: 0.2199 - learning_rate: 5.0000e-04
# Epoch 73/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0597 - mean_squared_error: 0.0597 - val_loss: 0.2206 - val_mean_squared_error: 0.2206 - learning_rate: 5.0000e-04
# Epoch 74/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 0.2218 - val_mean_squared_error: 0.2218 - learning_rate: 5.0000e-04
# Epoch 75/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0693 - mean_squared_error: 0.0693 - val_loss: 0.2105 - val_mean_squared_error: 0.2105 - learning_rate: 5.0000e-04
# Epoch 76/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0657 - mean_squared_error: 0.0657 - val_loss: 0.2148 - val_mean_squared_error: 0.2148 - learning_rate: 5.0000e-04
# Epoch 77/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.0596 - mean_squared_error: 0.0596
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0596 - mean_squared_error: 0.0596 - val_loss: 0.2099 - val_mean_squared_error: 0.2099 - learning_rate: 5.0000e-04
# Epoch 78/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0533 - mean_squared_error: 0.0533 - val_loss: 0.2008 - val_mean_squared_error: 0.2008 - learning_rate: 2.5000e-04
# Epoch 79/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0438 - mean_squared_error: 0.0438 - val_loss: 0.2002 - val_mean_squared_error: 0.2002 - learning_rate: 2.5000e-04
# Epoch 80/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 170ms/step - loss: 0.0415 - mean_squared_error: 0.0415 - val_loss: 0.2004 - val_mean_squared_error: 0.2004 - learning_rate: 2.5000e-04
# Epoch 81/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.1995 - val_mean_squared_error: 0.1995 - learning_rate: 2.5000e-04
# Epoch 82/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.2038 - val_mean_squared_error: 0.2038 - learning_rate: 2.5000e-04
# Epoch 83/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.2024 - val_mean_squared_error: 0.2024 - learning_rate: 2.5000e-04
# Epoch 84/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 168ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.2026 - val_mean_squared_error: 0.2026 - learning_rate: 2.5000e-04
# Epoch 85/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.2058 - val_mean_squared_error: 0.2058 - learning_rate: 2.5000e-04
# Epoch 86/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0360 - mean_squared_error: 0.0360 - val_loss: 0.2057 - val_mean_squared_error: 0.2057 - learning_rate: 2.5000e-04
# Epoch 87/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.2050 - val_mean_squared_error: 0.2050 - learning_rate: 2.5000e-04
# Epoch 88/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0348 - mean_squared_error: 0.0348
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0348 - mean_squared_error: 0.0348 - val_loss: 0.2057 - val_mean_squared_error: 0.2057 - learning_rate: 2.5000e-04
# Epoch 89/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.2005 - val_mean_squared_error: 0.2005 - learning_rate: 1.2500e-04
# Epoch 90/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.2013 - val_mean_squared_error: 0.2013 - learning_rate: 1.2500e-04
# Epoch 91/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.2007 - val_mean_squared_error: 0.2007 - learning_rate: 1.2500e-04
# Epoch 92/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.2023 - val_mean_squared_error: 0.2023 - learning_rate: 1.2500e-04
# Epoch 93/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0303 - mean_squared_error: 0.0303 - val_loss: 0.2026 - val_mean_squared_error: 0.2026 - learning_rate: 1.2500e-04
# Epoch 94/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.1989 - val_mean_squared_error: 0.1989 - learning_rate: 1.2500e-04
# Epoch 95/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 169ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.2015 - val_mean_squared_error: 0.2015 - learning_rate: 1.2500e-04
# Epoch 96/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 168ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.2000 - val_mean_squared_error: 0.2000 - learning_rate: 1.2500e-04
# Epoch 97/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 170ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.1999 - val_mean_squared_error: 0.1999 - learning_rate: 1.2500e-04
# Epoch 98/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.2010 - val_mean_squared_error: 0.2010 - learning_rate: 1.2500e-04
# Epoch 99/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 169ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.2047 - val_mean_squared_error: 0.2047 - learning_rate: 1.2500e-04
# Epoch 100/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 42s 168ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.1994 - val_mean_squared_error: 0.1994 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 94.
#
# TRAINING COMPLETED!
# ==============================
# Total training time: 120.1 minutes
# Average per epoch: 72.1 seconds
# Best validation loss: 0.1989
# Final training loss: 0.0272
# Total epochs completed: 100

# %%
#Section 7

# EVALUATION FOR 75% DATASET
if 'history' in locals():
    print("EVALUATING 75% DATASET RESULTS...")
    print("=" * 45)

    # Make predictions
    print("Making predictions on test set...")
    y_pred_test = fast_model.predict([XD_test, XT_test], batch_size=BATCH_SIZE, verbose=1)

    # Calculate metrics
    print("Computing metrics...")
    test_mse = mean_squared_error(y_test, y_pred_test)
    test_ci = concordance_index(y_test, y_pred_test)

    print(f"\n75% DATASET RESULTS:")
    print("=" * 30)
    print(f"Test MSE: {test_mse:.6f}")
    print(f"Test CI: {test_ci:.6f}")

    # Performance comparison across all datasets
    print(f"\nPERFORMANCE PROGRESSION:")
    print("-" * 35)
    print(f"   10% dataset: CI = 0.6552")
    print(f"   75% dataset: CI = {test_ci:.4f}")

    # Comparison with literature
    print(f"\nLiterature Comparison:")
    print("-" * 25)
    print(f"   Paper DeepDTA: 0.863")
    print(f"   Our 75% model: {test_ci:.3f}")
    print(f"   Performance ratio: {test_ci/0.863:.1%}")

    # Performance analysis
    if test_ci >= 0.72:
        print(f"\nEXCELLENT! CI ≥ 0.72 - Ready for full dataset!")
        print(f"Next step: Try 100% dataset for CI ≈ 0.80+")
    elif test_ci >= 0.68:
        print(f"\nGOOD! CI ≥ 0.68 - Model scaling properly")
        print(f"Continue scaling to 100% dataset")
    else:
        print(f"\nCI < 0.68 - May need model architecture improvements")

    # Additional metrics
    mae = np.mean(np.abs(y_test - y_pred_test.flatten()))
    rmse = np.sqrt(test_mse)
    r2 = 1 - np.var(y_test - y_pred_test.flatten()) / np.var(y_test)

    print(f"\nAdditional Metrics:")
    print("-" * 20)
    print(f"MAE: {mae:.6f}")
    print(f"RMSE: {rmse:.6f}")
    print(f"R² Score: {r2:.6f}")

    print("\n" + "="*45)
    print("75% DATASET EVALUATION COMPLETED!")
    print("="*45)

else:
    print("Cannot evaluate - training not completed")
# Out:
# EVALUATING 75% DATASET RESULTS...
# =============================================
# Making predictions on test set...
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# Computing metrics...
#
# 75% DATASET RESULTS:
# ==============================
# Test MSE: 0.198016
# Test CI: 0.856727
#
# PERFORMANCE PROGRESSION:
# -----------------------------------
#    10% dataset: CI = 0.6552
#    75% dataset: CI = 0.8567
#
# Literature Comparison:
# -------------------------
#    Paper DeepDTA: 0.863
#    Our 75% model: 0.857
#    Performance ratio: 99.3%
#
# EXCELLENT! CI ≥ 0.72 - Ready for full dataset!
# Next step: Try 100% dataset for CI ≈ 0.80+
#
# Additional Metrics:
# --------------------
# MAE: 0.259411
# RMSE: 0.444990
# R² Score: 0.716820
#
# =============================================
# 75% DATASET EVALUATION COMPLETED!
# =============================================
