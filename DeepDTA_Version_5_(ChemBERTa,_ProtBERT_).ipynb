# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezafarhadi01/DrugDesignCourse-FinalProject/blob/main/DeepDTA_Version_5_(ChemBERTa%2C_ProtBERT_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import numpy as np
import pickle
import tensorflow as tf
from tensorflow.keras import layers, Model
from sklearn.metrics import mean_squared_error
import os
import warnings
import zipfile
import time

warnings.filterwarnings('ignore')

# --- NEW: Install and import necessary libraries for pre-trained models ---
# This block checks if the required libraries are installed and installs them if not.
try:
    import torch
    from transformers import AutoTokenizer, AutoModel
except ImportError:
    import subprocess
    import sys
    print("Installing PyTorch and Transformers from Hugging Face...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "torch", "transformers"])
    import torch
    from transformers import AutoTokenizer, AutoModel

try:
    from tqdm import tqdm
except ImportError:
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "tqdm"])
    from tqdm import tqdm

# Basic optimizations
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['OMP_NUM_THREADS'] = str(os.cpu_count())

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# --- Constants ---
KIBA_DATA_PATH = './kiba'
# --- NEW: Define model names and their corresponding embedding dimensions ---
PROTBERT_MODEL_NAME = "Rostlab/prot_bert_bfd"
CHEMBERTA_MODEL_NAME = "seyonec/ChemBERTa-zinc-base-v1"
PROTBERT_EMBED_DIM = 1024
CHEMBERTA_EMBED_DIM = 768

# Enable XLA for faster computation on GPU/TPU
try:
    tf.config.optimizer.set_jit(True)
except:
    pass

# --- NEW HELPER FUNCTION ---
def generate_embeddings(sequences, model_name, saved_path, max_len=512, batch_size=32):
    """
    Generates embeddings for a list of sequences using a pre-trained transformer model.
    It saves the computed embeddings to a file to avoid re-computing them on subsequent runs.
    """
    if os.path.exists(saved_path):
        print(f"Loading pre-computed embeddings from {saved_path}...")
        return np.load(saved_path)

    print(f"Generating embeddings with {model_name}. This may take a while...")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()

    all_embeddings = []

    for i in tqdm(range(0, len(sequences), batch_size), desc=f"Embedding {os.path.basename(saved_path)}"):
        batch_seqs = sequences[i:i + batch_size]
        if "prot_bert" in model_name.lower():
            batch_seqs = [" ".join(list(seq)) for seq in batch_seqs]
        inputs = tokenizer(batch_seqs, return_tensors="pt", truncation=True, padding=True, max_length=max_len).to(device)
        with torch.no_grad():
            outputs = model(**inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
        all_embeddings.append(embeddings)

    final_embeddings = np.concatenate(all_embeddings, axis=0)
    print(f"Saving embeddings to {saved_path}...")
    np.save(saved_path, final_embeddings)
    return final_embeddings

def concordance_index(y_true, y_pred):
    """Optimized concordance index calculation. This function is UNCHANGED."""
    y_true = y_true.flatten().astype(np.float32)
    y_pred = y_pred.flatten().astype(np.float32)
    mask = ~(np.isnan(y_true) | np.isnan(y_pred))
    y_true, y_pred = y_true[mask], y_pred[mask]
    if len(y_true) < 2: return 0.0
    if len(y_true) > 10000:
        indices = np.random.choice(len(y_true), 10000, replace=False)
        y_true, y_pred = y_true[indices], y_pred[indices]
    n = len(y_true)
    indices = np.arange(n)
    i_indices, j_indices = np.meshgrid(indices, indices, indexing='ij')
    mask = i_indices < j_indices
    y_true_i, y_true_j = y_true[i_indices[mask]], y_true[j_indices[mask]]
    y_pred_i, y_pred_j = y_pred[i_indices[mask]], y_pred[j_indices[mask]]
    different_mask = y_true_i != y_true_j
    if np.sum(different_mask) == 0: return 0.0
    y_true_i, y_true_j = y_true_i[different_mask], y_true_j[different_mask]
    y_pred_i, y_pred_j = y_pred_i[different_mask], y_pred_j[different_mask]
    concordant = ((y_true_i > y_true_j) & (y_pred_i > y_pred_j)) | \
                 ((y_true_i < y_true_j) & (y_pred_i < y_pred_j))
    ties = (y_pred_i == y_pred_j)
    return (np.sum(concordant) + 0.5 * np.sum(ties)) / len(y_true_i)

class OptimizedKibaDataProcessor:
    """
    MODIFIED: This data processor now uses pre-trained models to generate
    feature vectors instead of character-level integer encoding.
    The class name is UNCHANGED.
    """
    def __init__(self, data_path='./kiba'):
        self.data_path = data_path

    def load_data(self):
        """This internal method for loading the raw files is UNCHANGED."""
        ligands_path = os.path.join(self.data_path, 'ligands_can.txt')
        proteins_path = os.path.join(self.data_path, 'proteins.txt')
        with open(ligands_path, 'r') as f: drugs_dict = json.load(f)
        with open(proteins_path, 'r') as f: proteins_dict = json.load(f)
        y_file_path = os.path.join(self.data_path, 'Y')
        with open(y_file_path, 'rb') as f: affinity_matrix = pickle.load(f, encoding='latin1')

        valid_indices = np.where(~np.isnan(affinity_matrix))
        total_valid_pairs = len(valid_indices[0])
        all_indices = np.arange(total_valid_pairs)
        np.random.seed(42)
        np.random.shuffle(all_indices)
        split_point = int(0.8 * total_valid_pairs)
        train_indices = all_indices[:split_point]
        test_indices = all_indices[split_point:]
        return drugs_dict, proteins_dict, affinity_matrix, train_indices, test_indices, valid_indices

    def process_data(self):
        """
        MODIFIED: This method now orchestrates the generation of embeddings
        using the pre-trained models and assembles the final datasets.
        """
        data = self.load_data()
        if data is None: return None
        drugs_dict, proteins_dict, affinity_matrix, train_indices, test_indices, valid_indices = data

        all_drug_smiles = list(drugs_dict.values())
        all_protein_seqs = list(proteins_dict.values())

        drug_embeddings = generate_embeddings(all_drug_smiles, CHEMBERTA_MODEL_NAME, os.path.join(self.data_path, "chemberta_embeddings.npy"))
        prot_embeddings = generate_embeddings(all_protein_seqs, PROTBERT_MODEL_NAME, os.path.join(self.data_path, "protbert_embeddings.npy"))

        def create_dataset_from_embeddings(indices, set_name):
            """Helper to build datasets by selecting pre-computed vectors."""
            print(f"Assembling {set_name} set from pre-computed embeddings...")
            original_drug_indices = valid_indices[0][indices]
            original_prot_indices = valid_indices[1][indices]
            drug_vectors = drug_embeddings[original_drug_indices]
            prot_vectors = prot_embeddings[original_prot_indices]
            affinities = affinity_matrix[original_drug_indices, original_prot_indices]
            return drug_vectors, prot_vectors, affinities.astype(np.float32)

        XD_train, XT_train, y_train = create_dataset_from_embeddings(train_indices, "training")
        XD_test, XT_test, y_test = create_dataset_from_embeddings(test_indices, "test")
        return (XD_train, XT_train, y_train), (XD_test, XT_test, y_test)

def build_fast_deepdta_model(drug_embed_dim, prot_embed_dim):
    """
    MODIFIED: Builds the DTA model that accepts pre-computed embedding vectors as input.
    The function name is UNCHANGED, but the parameters are different.
    The original Embedding and Flatten layers are removed.
    """
    DENSE_UNITS_1 = 1024
    DENSE_UNITS_2 = 512
    DROPOUT_RATE = 0.2
    LEARNING_RATE = 0.001

    drug_input = layers.Input(shape=(drug_embed_dim,), name='drug_input_vector')
    prot_input = layers.Input(shape=(prot_embed_dim,), name='protein_input_vector')
    combined = layers.Concatenate(axis=-1, name='concatenate_branches')([drug_input, prot_input])
    fc1 = layers.Dense(DENSE_UNITS_1, activation='relu', name='fully_connected_1')(combined)
    bn1 = layers.BatchNormalization(name='batch_norm_1')(fc1)
    drop1 = layers.Dropout(DROPOUT_RATE, name='dropout_1')(bn1)
    fc2 = layers.Dense(DENSE_UNITS_2, activation='relu', name='fully_connected_2')(drop1)
    bn2 = layers.BatchNormalization(name='batch_norm_2')(fc2)
    drop2 = layers.Dropout(DROPOUT_RATE, name='dropout_2')(bn2)
    output = layers.Dense(1, activation='linear', name='output')(drop2)

    model = Model(inputs=[drug_input, prot_input], outputs=output, name='DTA_with_Pretrained_Embeddings')
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])
    return model

# %%
# Define the path to your zip file
zip_file_path = '/content/data.zip' # Replace with the actual path to your .zip file

# Define the directory where you want to extract the contents
# If the directory doesn't exist, it will be created.
extract_dir = '/content/' # You can change this to your desired extraction path

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Extract the zip file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"Successfully extracted '{zip_file_path}' to '{extract_dir}'")
except FileNotFoundError:
    print(f"Error: The file '{zip_file_path}' was not found.")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Optional: List the contents of the extracted directory to verify
print("\nContents of the extracted directory:")
for item in os.listdir(extract_dir):
    print(os.path.join(extract_dir, item))
# Out:
# Successfully extracted '/content/data.zip' to '/content/'
#
# Contents of the extracted directory:
# /content/.config
# /content/data.zip
# /content/davis
# /content/kiba
# /content/sample_data

# %%
# Process the data
print("=== Starting Data Processing ===")

# Check if data path exists
if not os.path.exists(KIBA_DATA_PATH):
    print(f"Data path not found: {KIBA_DATA_PATH}")
    print("Please make sure you have uploaded and extracted the kiba folder.")
    print("Current directory contents:")
    for item in os.listdir('.'):
        print(f"  - {item}")
else:
    print(f"Data path found: {KIBA_DATA_PATH}")

    # Now OptimizedKibaDataProcessor should be available
    processor = OptimizedKibaDataProcessor(data_path=KIBA_DATA_PATH)

    processed_data = processor.process_data()
    if processed_data is None:
        print("Failed to process data. Please check your data files.")
    else:
        # CORRECTED: Unpack the new two-part tuple returned by the updated process_data function.
        # The vocabulary sizes are no longer returned.
        (XD_train, XT_train, y_train), (XD_test, XT_test, y_test) = processed_data

        print("Data processing completed successfully!")
        print(f"Data shapes:")
        print(f"   XD_train: {XD_train.shape}, dtype: {XD_train.dtype}")
        print(f"   XT_train: {XT_train.shape}, dtype: {XT_train.dtype}")
        print(f"   y_train: {y_train.shape}, dtype: {y_train.dtype}")
        print(f"   XD_test: {XD_test.shape}, dtype: {XD_test.dtype}")
        print(f"   XT_test: {XT_test.shape}, dtype: {XT_test.dtype}")
        print(f"   y_test: {y_test.shape}, dtype: {y_test.dtype}")
# Out:
# === Starting Data Processing ===
# Data path found: ./kiba
# Generating embeddings with seyonec/ChemBERTa-zinc-base-v1. This may take a while...
# Using device: cpu
# tokenizer_config.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/501 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/179M [00:00<?, ?B/s]
# Embedding chemberta_embeddings.npy:   0%|          | 0/66 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/179M [00:00<?, ?B/s]
# Embedding chemberta_embeddings.npy: 100%|██████████| 66/66 [03:10<00:00,  2.89s/it]
# Saving embeddings to ./kiba/chemberta_embeddings.npy...
# Generating embeddings with Rostlab/prot_bert_bfd. This may take a while...
# Using device: cpu
# tokenizer_config.json:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/361 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/81.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# Embedding protbert_embeddings.npy:   0%|          | 0/8 [00:00<?, ?it/s]
# Embedding protbert_embeddings.npy:  12%|█▎        | 1/8 [03:02<21:18, 182.58s/it]
# Embedding protbert_embeddings.npy:  25%|██▌       | 2/8 [05:59<17:55, 179.28s/it]
# Embedding protbert_embeddings.npy:  38%|███▊      | 3/8 [08:55<14:49, 177.93s/it]
# Embedding protbert_embeddings.npy:  50%|█████     | 4/8 [11:55<11:54, 178.72s/it]
# Embedding protbert_embeddings.npy:  62%|██████▎   | 5/8 [14:56<08:57, 179.28s/it]
# Embedding protbert_embeddings.npy:  75%|███████▌  | 6/8 [17:53<05:56, 178.50s/it]
# Embedding protbert_embeddings.npy:  88%|████████▊ | 7/8 [20:50<02:58, 178.00s/it]
# Embedding protbert_embeddings.npy: 100%|██████████| 8/8 [21:16<00:00, 159.53s/it]
# Saving embeddings to ./kiba/protbert_embeddings.npy...
# Assembling training set from pre-computed embeddings...
# Assembling test set from pre-computed embeddings...
# Data processing completed successfully!
# Data shapes:
#    XD_train: (94603, 768), dtype: float32
#    XT_train: (94603, 1024), dtype: float32
#    y_train: (94603,), dtype: float32
#    XD_test: (23651, 768), dtype: float32
#    XT_test: (23651, 1024), dtype: float32
#    y_test: (23651,), dtype: float32

# %%
# CONFIGURATION FOR 75% DATASET
REDUCE_DATASET = True
DATASET_FRACTION = 0.75
EPOCHS = 100
BATCH_SIZE = 256
VALIDATION_SPLIT = 0.1

print("CONFIGURATION FOR 75% DATASET:")
print("=" * 50)
print(f"Dataset fraction: {DATASET_FRACTION*100}%")
print(f"Batch size: {BATCH_SIZE}")
print(f"Epochs: {EPOCHS}")

# Proper dataset reduction
if 'XD_train' in locals() and len(XD_train) > 1000:  # Only if we have full data

    # Use the ORIGINAL full dataset, not the already reduced one
    print(f"Using original dataset: {len(XD_train):,} training samples")

    # Calculate correct sample sizes
    n_train = int(len(XD_train) * DATASET_FRACTION)
    n_test = int(len(XD_test) * DATASET_FRACTION)

    print(f"Target training samples: {n_train:,}")
    print(f"Target test samples: {n_test:,}")

    # Randomly sample subset
    np.random.seed(42)  # For reproducibility
    train_indices = np.random.choice(len(XD_train), n_train, replace=False)
    test_indices = np.random.choice(len(XD_test), n_test, replace=False)

    XD_train_75 = XD_train[train_indices]
    XT_train_75 = XT_train[train_indices]
    y_train_75 = y_train[train_indices]

    XD_test_75 = XD_test[test_indices]
    XT_test_75 = XT_test[test_indices]
    y_test_75 = y_test[test_indices]

    # Calculate batches per epoch
    batches_per_epoch = len(XD_train_75) // BATCH_SIZE

    print(f"CORRECTED DATASET:")
    print(f"   Training: {len(XD_train_75):,} samples")
    print(f"   Test: {len(XD_test_75):,} samples")
    print(f"   Batches per epoch: {batches_per_epoch}")
    print(f"   Much more stable training expected!")

    # Use corrected datasets
    XD_train = XD_train_75
    XT_train = XT_train_75
    y_train = y_train_75
    XD_test = XD_test_75
    XT_test = XT_test_75
    y_test = y_test_75

    print("Ready for corrected training!")
elif 'XD_train' in locals():
    print(f"Current dataset already reduced: {len(XD_train):,} samples")
    print("Please restart and run data processing again for full dataset")

    # Still apply batch size fix for current data
    batches_per_epoch = len(XD_train) // BATCH_SIZE
    print(f"Batches per epoch with current data: {batches_per_epoch}")
else:
    print("Cannot apply optimizations - data not loaded yet!")
# Out:
# CONFIGURATION FOR 75% DATASET:
# ==================================================
# Dataset fraction: 75.0%
# Batch size: 256
# Epochs: 100
# Using original dataset: 94,603 training samples
# Target training samples: 70,952
# Target test samples: 17,738
# CORRECTED DATASET:
#    Training: 70,952 samples
#    Test: 17,738 samples
#    Batches per epoch: 277
#    Much more stable training expected!
# Ready for corrected training!

# %%
# Build the model (only if data processing was successful)
if 'XD_train' in locals():
    print("\n=== Building Optimized Model ===")

    # CORRECTED: Build the model by passing the new, required embedding dimensions
    # instead of the obsolete vocabulary sizes and max lengths.
    fast_model = build_fast_deepdta_model(
        drug_embed_dim=CHEMBERTA_EMBED_DIM,
        prot_embed_dim=PROTBERT_EMBED_DIM
    )

    print("\n=== Model Summary ===")
    fast_model.summary()
    print("Model built successfully!")
else:
    print("Cannot build model - data processing failed or incomplete")
# Out:
# === Building Optimized Model ===
#
# === Model Summary ===
# Model: "DTA_with_Pretrained_Embeddings"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ drug_input_vector   │ (None, 768)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_input_vect… │ (None, 1024)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_branch… │ (None, 1792)      │          0 │ drug_input_vecto… │
# │ (Concatenate)       │                   │            │ protein_input_ve… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_1   │ (None, 1024)      │  1,836,032 │ concatenate_bran… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_norm_1        │ (None, 1024)      │      4,096 │ fully_connected_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ batch_norm_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_2   │ (None, 512)       │    524,800 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_norm_2        │ (None, 512)       │      2,048 │ fully_connected_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ batch_norm_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │        513 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,367,489 (9.03 MB)
#  Trainable params: 2,364,417 (9.02 MB)
#  Non-trainable params: 3,072 (12.00 KB)
# Model built successfully!

# %%
# OPTIMIZED TRAINING
if 'fast_model' in locals():
    print("STARTING OPTIMIZED TRAINING...")
    print("=" * 55)

    # Training configuration summary
    print(f"Configuration Summary:")
    print(f"   Dataset fraction: {DATASET_FRACTION*100}%")
    print(f"   Batch size: {BATCH_SIZE}")
    print(f"   Epochs: {EPOCHS}")
    print(f"   Training samples: {len(XD_train):,}")
    print(f"   Test samples: {len(XD_test):,}")
    print(f"   Batches per epoch: {len(XD_train) // BATCH_SIZE}")

    # Optimized callbacks
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=15,  # More patience for larger dataset
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=7,   # More patience for larger dataset
            min_lr=1e-6,
            verbose=1
        )
    ]

    print(f"\nStarting training...")
    print("=" * 55)

    start_time = time.time()

    # Train the model
    history = fast_model.fit(
        x=[XD_train, XT_train],
        y=y_train,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        validation_split=VALIDATION_SPLIT,
        callbacks=callbacks,
        verbose=1
    )

    end_time = time.time()
    training_time = end_time - start_time

    print(f"\nTRAINING COMPLETED!")
    print("=" * 30)
    print(f"Total training time: {training_time/60:.1f} minutes")
    print(f"Average per epoch: {training_time/len(history.history['loss']):.1f} seconds")
    print(f"Best validation loss: {min(history.history['val_loss']):.4f}")
    print(f"Final training loss: {history.history['loss'][-1]:.4f}")
    print(f"Total epochs completed: {len(history.history['loss'])}")
else:
    print("Cannot start training - model not built")
# Out:
# STARTING OPTIMIZED TRAINING...
# =======================================================
# Configuration Summary:
#    Dataset fraction: 75.0%
#    Batch size: 256
#    Epochs: 100
#    Training samples: 70,952
#    Test samples: 17,738
#    Batches per epoch: 277
#
# Starting training...
# =======================================================
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 69ms/step - loss: 86.1424 - mean_squared_error: 86.1424 - val_loss: 0.9331 - val_mean_squared_error: 0.9331 - learning_rate: 0.0010
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - loss: 3.4220 - mean_squared_error: 3.4220 - val_loss: 0.7252 - val_mean_squared_error: 0.7252 - learning_rate: 0.0010
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - loss: 2.8077 - mean_squared_error: 2.8077 - val_loss: 0.6131 - val_mean_squared_error: 0.6131 - learning_rate: 0.0010
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - loss: 2.3033 - mean_squared_error: 2.3033 - val_loss: 0.6056 - val_mean_squared_error: 0.6056 - learning_rate: 0.0010
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - loss: 1.9671 - mean_squared_error: 1.9671 - val_loss: 0.5538 - val_mean_squared_error: 0.5538 - learning_rate: 0.0010
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 1.7254 - mean_squared_error: 1.7254 - val_loss: 0.7932 - val_mean_squared_error: 0.7932 - learning_rate: 0.0010
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 1.5006 - mean_squared_error: 1.5006 - val_loss: 0.5952 - val_mean_squared_error: 0.5952 - learning_rate: 0.0010
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - loss: 1.3400 - mean_squared_error: 1.3400 - val_loss: 0.5173 - val_mean_squared_error: 0.5173 - learning_rate: 0.0010
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - loss: 1.2280 - mean_squared_error: 1.2280 - val_loss: 0.8507 - val_mean_squared_error: 0.8507 - learning_rate: 0.0010
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 1.1057 - mean_squared_error: 1.1057 - val_loss: 0.5026 - val_mean_squared_error: 0.5026 - learning_rate: 0.0010
# Epoch 11/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 1.0307 - mean_squared_error: 1.0307 - val_loss: 0.5170 - val_mean_squared_error: 0.5170 - learning_rate: 0.0010
# Epoch 12/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.9683 - mean_squared_error: 0.9683 - val_loss: 0.6239 - val_mean_squared_error: 0.6239 - learning_rate: 0.0010
# Epoch 13/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.8977 - mean_squared_error: 0.8977 - val_loss: 0.4985 - val_mean_squared_error: 0.4985 - learning_rate: 0.0010
# Epoch 14/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.8500 - mean_squared_error: 0.8500 - val_loss: 0.5909 - val_mean_squared_error: 0.5909 - learning_rate: 0.0010
# Epoch 15/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.4466 - val_mean_squared_error: 0.4466 - learning_rate: 0.0010
# Epoch 16/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.7612 - mean_squared_error: 0.7612 - val_loss: 0.7171 - val_mean_squared_error: 0.7171 - learning_rate: 0.0010
# Epoch 17/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 55ms/step - loss: 0.7289 - mean_squared_error: 0.7289 - val_loss: 0.6134 - val_mean_squared_error: 0.6134 - learning_rate: 0.0010
# Epoch 18/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.7157 - mean_squared_error: 0.7157 - val_loss: 0.5912 - val_mean_squared_error: 0.5912 - learning_rate: 0.0010
# Epoch 19/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.6786 - mean_squared_error: 0.6786 - val_loss: 0.5996 - val_mean_squared_error: 0.5996 - learning_rate: 0.0010
# Epoch 20/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.6481 - mean_squared_error: 0.6481 - val_loss: 0.4882 - val_mean_squared_error: 0.4882 - learning_rate: 0.0010
# Epoch 21/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.6254 - mean_squared_error: 0.6254 - val_loss: 0.5147 - val_mean_squared_error: 0.5147 - learning_rate: 0.0010
# Epoch 22/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.6045 - mean_squared_error: 0.6045 - val_loss: 0.4306 - val_mean_squared_error: 0.4306 - learning_rate: 0.0010
# Epoch 23/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - loss: 0.5808 - mean_squared_error: 0.5808 - val_loss: 0.5727 - val_mean_squared_error: 0.5727 - learning_rate: 0.0010
# Epoch 24/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.5707 - mean_squared_error: 0.5707 - val_loss: 0.4409 - val_mean_squared_error: 0.4409 - learning_rate: 0.0010
# Epoch 25/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.5581 - mean_squared_error: 0.5581 - val_loss: 0.5355 - val_mean_squared_error: 0.5355 - learning_rate: 0.0010
# Epoch 26/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.5403 - mean_squared_error: 0.5403 - val_loss: 0.6869 - val_mean_squared_error: 0.6869 - learning_rate: 0.0010
# Epoch 27/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.5263 - mean_squared_error: 0.5263 - val_loss: 0.4736 - val_mean_squared_error: 0.4736 - learning_rate: 0.0010
# Epoch 28/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.5113 - mean_squared_error: 0.5113 - val_loss: 0.8187 - val_mean_squared_error: 0.8187 - learning_rate: 0.0010
# Epoch 29/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4959 - mean_squared_error: 0.4959
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.4959 - mean_squared_error: 0.4959 - val_loss: 0.4663 - val_mean_squared_error: 0.4663 - learning_rate: 0.0010
# Epoch 30/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 68ms/step - loss: 0.4688 - mean_squared_error: 0.4688 - val_loss: 0.4274 - val_mean_squared_error: 0.4274 - learning_rate: 5.0000e-04
# Epoch 31/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.4583 - mean_squared_error: 0.4583 - val_loss: 0.3740 - val_mean_squared_error: 0.3740 - learning_rate: 5.0000e-04
# Epoch 32/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.4509 - mean_squared_error: 0.4509 - val_loss: 0.4297 - val_mean_squared_error: 0.4297 - learning_rate: 5.0000e-04
# Epoch 33/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.4439 - mean_squared_error: 0.4439 - val_loss: 0.3785 - val_mean_squared_error: 0.3785 - learning_rate: 5.0000e-04
# Epoch 34/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.4348 - mean_squared_error: 0.4348 - val_loss: 0.5421 - val_mean_squared_error: 0.5421 - learning_rate: 5.0000e-04
# Epoch 35/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 73ms/step - loss: 0.4257 - mean_squared_error: 0.4257 - val_loss: 0.4659 - val_mean_squared_error: 0.4659 - learning_rate: 5.0000e-04
# Epoch 36/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - loss: 0.4344 - mean_squared_error: 0.4344 - val_loss: 0.4528 - val_mean_squared_error: 0.4528 - learning_rate: 5.0000e-04
# Epoch 37/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.4222 - mean_squared_error: 0.4222 - val_loss: 0.3510 - val_mean_squared_error: 0.3510 - learning_rate: 5.0000e-04
# Epoch 38/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.4173 - mean_squared_error: 0.4173 - val_loss: 0.4555 - val_mean_squared_error: 0.4555 - learning_rate: 5.0000e-04
# Epoch 39/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.4178 - mean_squared_error: 0.4178 - val_loss: 0.5404 - val_mean_squared_error: 0.5404 - learning_rate: 5.0000e-04
# Epoch 40/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.4083 - mean_squared_error: 0.4083 - val_loss: 0.5376 - val_mean_squared_error: 0.5376 - learning_rate: 5.0000e-04
# Epoch 41/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.4069 - mean_squared_error: 0.4069 - val_loss: 0.3819 - val_mean_squared_error: 0.3819 - learning_rate: 5.0000e-04
# Epoch 42/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.4024 - mean_squared_error: 0.4024 - val_loss: 0.3661 - val_mean_squared_error: 0.3661 - learning_rate: 5.0000e-04
# Epoch 43/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - loss: 0.3909 - mean_squared_error: 0.3909 - val_loss: 0.4449 - val_mean_squared_error: 0.4449 - learning_rate: 5.0000e-04
# Epoch 44/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3865 - mean_squared_error: 0.3865
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.3865 - mean_squared_error: 0.3865 - val_loss: 0.4249 - val_mean_squared_error: 0.4249 - learning_rate: 5.0000e-04
# Epoch 45/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.3753 - mean_squared_error: 0.3753 - val_loss: 0.3623 - val_mean_squared_error: 0.3623 - learning_rate: 2.5000e-04
# Epoch 46/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.3666 - mean_squared_error: 0.3666 - val_loss: 0.3094 - val_mean_squared_error: 0.3094 - learning_rate: 2.5000e-04
# Epoch 47/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.3629 - mean_squared_error: 0.3629 - val_loss: 0.3382 - val_mean_squared_error: 0.3382 - learning_rate: 2.5000e-04
# Epoch 48/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3580 - mean_squared_error: 0.3580 - val_loss: 0.3513 - val_mean_squared_error: 0.3513 - learning_rate: 2.5000e-04
# Epoch 49/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3592 - mean_squared_error: 0.3592 - val_loss: 0.5135 - val_mean_squared_error: 0.5135 - learning_rate: 2.5000e-04
# Epoch 50/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3546 - mean_squared_error: 0.3546 - val_loss: 0.3247 - val_mean_squared_error: 0.3247 - learning_rate: 2.5000e-04
# Epoch 51/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.3579 - mean_squared_error: 0.3579 - val_loss: 0.3205 - val_mean_squared_error: 0.3205 - learning_rate: 2.5000e-04
# Epoch 52/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3533 - mean_squared_error: 0.3533 - val_loss: 0.3493 - val_mean_squared_error: 0.3493 - learning_rate: 2.5000e-04
# Epoch 53/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3481 - mean_squared_error: 0.3481
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3480 - mean_squared_error: 0.3480 - val_loss: 0.4105 - val_mean_squared_error: 0.4105 - learning_rate: 2.5000e-04
# Epoch 54/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.3429 - mean_squared_error: 0.3429 - val_loss: 0.3082 - val_mean_squared_error: 0.3082 - learning_rate: 1.2500e-04
# Epoch 55/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - loss: 0.3336 - mean_squared_error: 0.3336 - val_loss: 0.2885 - val_mean_squared_error: 0.2885 - learning_rate: 1.2500e-04
# Epoch 56/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - loss: 0.3364 - mean_squared_error: 0.3364 - val_loss: 0.2952 - val_mean_squared_error: 0.2952 - learning_rate: 1.2500e-04
# Epoch 57/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3349 - mean_squared_error: 0.3349 - val_loss: 0.2912 - val_mean_squared_error: 0.2912 - learning_rate: 1.2500e-04
# Epoch 58/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3306 - mean_squared_error: 0.3306 - val_loss: 0.3106 - val_mean_squared_error: 0.3106 - learning_rate: 1.2500e-04
# Epoch 59/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.3265 - mean_squared_error: 0.3265 - val_loss: 0.3023 - val_mean_squared_error: 0.3023 - learning_rate: 1.2500e-04
# Epoch 60/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3283 - mean_squared_error: 0.3283 - val_loss: 0.2808 - val_mean_squared_error: 0.2808 - learning_rate: 1.2500e-04
# Epoch 61/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3290 - mean_squared_error: 0.3290 - val_loss: 0.2855 - val_mean_squared_error: 0.2855 - learning_rate: 1.2500e-04
# Epoch 62/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3276 - mean_squared_error: 0.3276 - val_loss: 0.2983 - val_mean_squared_error: 0.2983 - learning_rate: 1.2500e-04
# Epoch 63/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - loss: 0.3253 - mean_squared_error: 0.3253 - val_loss: 0.2858 - val_mean_squared_error: 0.2858 - learning_rate: 1.2500e-04
# Epoch 64/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - loss: 0.3284 - mean_squared_error: 0.3284 - val_loss: 0.2798 - val_mean_squared_error: 0.2798 - learning_rate: 1.2500e-04
# Epoch 65/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 0.3225 - mean_squared_error: 0.3225 - val_loss: 0.2838 - val_mean_squared_error: 0.2838 - learning_rate: 1.2500e-04
# Epoch 66/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3236 - mean_squared_error: 0.3236 - val_loss: 0.2803 - val_mean_squared_error: 0.2803 - learning_rate: 1.2500e-04
# Epoch 67/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.3187 - mean_squared_error: 0.3187 - val_loss: 0.2792 - val_mean_squared_error: 0.2792 - learning_rate: 1.2500e-04
# Epoch 68/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3174 - mean_squared_error: 0.3174 - val_loss: 0.2928 - val_mean_squared_error: 0.2928 - learning_rate: 1.2500e-04
# Epoch 69/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - loss: 0.3189 - mean_squared_error: 0.3189 - val_loss: 0.3184 - val_mean_squared_error: 0.3184 - learning_rate: 1.2500e-04
# Epoch 70/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3206 - mean_squared_error: 0.3206 - val_loss: 0.2691 - val_mean_squared_error: 0.2691 - learning_rate: 1.2500e-04
# Epoch 71/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.3171 - mean_squared_error: 0.3171 - val_loss: 0.2864 - val_mean_squared_error: 0.2864 - learning_rate: 1.2500e-04
# Epoch 72/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3143 - mean_squared_error: 0.3143 - val_loss: 0.2947 - val_mean_squared_error: 0.2947 - learning_rate: 1.2500e-04
# Epoch 73/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3114 - mean_squared_error: 0.3114 - val_loss: 0.2838 - val_mean_squared_error: 0.2838 - learning_rate: 1.2500e-04
# Epoch 74/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3132 - mean_squared_error: 0.3132 - val_loss: 0.2850 - val_mean_squared_error: 0.2850 - learning_rate: 1.2500e-04
# Epoch 75/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 0.3127 - mean_squared_error: 0.3127 - val_loss: 0.3059 - val_mean_squared_error: 0.3059 - learning_rate: 1.2500e-04
# Epoch 76/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3139 - mean_squared_error: 0.3139 - val_loss: 0.2849 - val_mean_squared_error: 0.2849 - learning_rate: 1.2500e-04
# Epoch 77/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.3117 - mean_squared_error: 0.3117
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.3117 - mean_squared_error: 0.3117 - val_loss: 0.3006 - val_mean_squared_error: 0.3006 - learning_rate: 1.2500e-04
# Epoch 78/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.3089 - mean_squared_error: 0.3089 - val_loss: 0.2676 - val_mean_squared_error: 0.2676 - learning_rate: 6.2500e-05
# Epoch 79/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3056 - mean_squared_error: 0.3056 - val_loss: 0.2710 - val_mean_squared_error: 0.2710 - learning_rate: 6.2500e-05
# Epoch 80/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.3069 - mean_squared_error: 0.3069 - val_loss: 0.2681 - val_mean_squared_error: 0.2681 - learning_rate: 6.2500e-05
# Epoch 81/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 57ms/step - loss: 0.3050 - mean_squared_error: 0.3050 - val_loss: 0.2648 - val_mean_squared_error: 0.2648 - learning_rate: 6.2500e-05
# Epoch 82/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - loss: 0.3004 - mean_squared_error: 0.3004 - val_loss: 0.2682 - val_mean_squared_error: 0.2682 - learning_rate: 6.2500e-05
# Epoch 83/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - loss: 0.3064 - mean_squared_error: 0.3064 - val_loss: 0.2681 - val_mean_squared_error: 0.2681 - learning_rate: 6.2500e-05
# Epoch 84/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - loss: 0.3012 - mean_squared_error: 0.3012 - val_loss: 0.2644 - val_mean_squared_error: 0.2644 - learning_rate: 6.2500e-05
# Epoch 85/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 61ms/step - loss: 0.3017 - mean_squared_error: 0.3017 - val_loss: 0.2703 - val_mean_squared_error: 0.2703 - learning_rate: 6.2500e-05
# Epoch 86/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 0.3000 - mean_squared_error: 0.3000 - val_loss: 0.2664 - val_mean_squared_error: 0.2664 - learning_rate: 6.2500e-05
# Epoch 87/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - loss: 0.2992 - mean_squared_error: 0.2992 - val_loss: 0.2683 - val_mean_squared_error: 0.2683 - learning_rate: 6.2500e-05
# Epoch 88/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - loss: 0.2981 - mean_squared_error: 0.2981 - val_loss: 0.2673 - val_mean_squared_error: 0.2673 - learning_rate: 6.2500e-05
# Epoch 89/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - loss: 0.2967 - mean_squared_error: 0.2967 - val_loss: 0.2661 - val_mean_squared_error: 0.2661 - learning_rate: 6.2500e-05
# Epoch 90/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.3004 - mean_squared_error: 0.3004 - val_loss: 0.2618 - val_mean_squared_error: 0.2618 - learning_rate: 6.2500e-05
# Epoch 91/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 0.3004 - mean_squared_error: 0.3004 - val_loss: 0.2747 - val_mean_squared_error: 0.2747 - learning_rate: 6.2500e-05
# Epoch 92/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - loss: 0.2968 - mean_squared_error: 0.2968 - val_loss: 0.2734 - val_mean_squared_error: 0.2734 - learning_rate: 6.2500e-05
# Epoch 93/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 0.2994 - mean_squared_error: 0.2994 - val_loss: 0.2631 - val_mean_squared_error: 0.2631 - learning_rate: 6.2500e-05
# Epoch 94/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.2990 - mean_squared_error: 0.2990 - val_loss: 0.2643 - val_mean_squared_error: 0.2643 - learning_rate: 6.2500e-05
# Epoch 95/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - loss: 0.2980 - mean_squared_error: 0.2980 - val_loss: 0.2716 - val_mean_squared_error: 0.2716 - learning_rate: 6.2500e-05
# Epoch 96/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 62ms/step - loss: 0.3000 - mean_squared_error: 0.3000 - val_loss: 0.2713 - val_mean_squared_error: 0.2713 - learning_rate: 6.2500e-05
# Epoch 97/100
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2939 - mean_squared_error: 0.2939
# Epoch 97: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.2939 - mean_squared_error: 0.2939 - val_loss: 0.2658 - val_mean_squared_error: 0.2658 - learning_rate: 6.2500e-05
# Epoch 98/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.2959 - mean_squared_error: 0.2959 - val_loss: 0.2593 - val_mean_squared_error: 0.2593 - learning_rate: 3.1250e-05
# Epoch 99/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - loss: 0.2958 - mean_squared_error: 0.2958 - val_loss: 0.2626 - val_mean_squared_error: 0.2626 - learning_rate: 3.1250e-05
# Epoch 100/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 58ms/step - loss: 0.2951 - mean_squared_error: 0.2951 - val_loss: 0.2622 - val_mean_squared_error: 0.2622 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 98.
#
# TRAINING COMPLETED!
# ==============================
# Total training time: 29.9 minutes
# Average per epoch: 17.9 seconds
# Best validation loss: 0.2593
# Final training loss: 0.2937
# Total epochs completed: 100

# %%
# EVALUATION
if 'history' in locals():
    print("EVALUATING RESULTS...")
    print("=" * 45)

    # Make predictions
    print("Making predictions on test set...")
    y_pred_test = fast_model.predict([XD_test, XT_test], batch_size=BATCH_SIZE, verbose=1)

    # Calculate metrics
    print("Computing metrics...")
    test_mse = mean_squared_error(y_test, y_pred_test)
    test_ci = concordance_index(y_test, y_pred_test)

    print(f"\nFINAL RESULTS:")
    print("=" * 30)
    print(f"Test MSE: {test_mse:.6f}")
    print(f"Test CI: {test_ci:.6f}")

    # Performance comparison
    print(f"\nPERFORMANCE PROGRESSION:")
    print("-" * 35)
    print(f"   Our model: CI = {test_ci:.4f}")

    # Comparison with literature
    print(f"\nLiterature Comparison:")
    print("-" * 25)
    print(f"   Paper DeepDTA: 0.863")
    print(f"   Our model: {test_ci:.3f}")
    print(f"   Performance ratio: {test_ci/0.863:.1%}")

    # Performance analysis
    if test_ci >= 0.8:
        print(f"\nEXCELLENT! CI is high, showing strong predictive power.")
    elif test_ci >= 0.7:
        print(f"\nGOOD! The model shows solid predictive performance.")
    else:
        print(f"\nNEEDS IMPROVEMENT: CI is lower than desired. Consider hyperparameter tuning or architectural changes.")

    # Additional metrics
    mae = np.mean(np.abs(y_test - y_pred_test.flatten()))
    rmse = np.sqrt(test_mse)
    # A simple way to calculate R-squared
    r2 = 1 - (np.sum((y_test - y_pred_test.flatten())**2) / np.sum((y_test - np.mean(y_test))**2))


    print(f"\nAdditional Metrics:")
    print("-" * 20)
    print(f"MAE: {mae:.6f}")
    print(f"RMSE: {rmse:.6f}")
    print(f"R² Score: {r2:.6f}")

    print("\n" + "="*45)
    print("EVALUATION COMPLETED!")
    print("="*45)
else:
    print("Cannot evaluate - training not completed")
# Out:
# EVALUATING RESULTS...
# =============================================
# Making predictions on test set...
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
# Computing metrics...
#
# FINAL RESULTS:
# ==============================
# Test MSE: 0.272786
# Test CI: 0.803441
#
# PERFORMANCE PROGRESSION:
# -----------------------------------
#    Our model: CI = 0.8034
#
# Literature Comparison:
# -------------------------
#    Paper DeepDTA: 0.863
#    Our model: 0.803
#    Performance ratio: 93.1%
#
# EXCELLENT! CI is high, showing strong predictive power.
#
# Additional Metrics:
# --------------------
# MAE: 0.344245
# RMSE: 0.522289
# R² Score: 0.608723
#
# =============================================
# EVALUATION COMPLETED!
# =============================================
