# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezafarhadi01/DrugDesignCourse-FinalProject/blob/main/DeepDTA_Version_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Section 1

import json
import numpy as np
import pickle
import tensorflow as tf
from tensorflow.keras import layers, Model
from sklearn.metrics import mean_squared_error
import os
import warnings

warnings.filterwarnings('ignore')

# Install and import tqdm for progress bars
try:
    from tqdm import tqdm
except ImportError:
    import subprocess
    import sys
    subprocess.check_call([sys.executable, "-m", "pip", "install", "tqdm"])
    from tqdm import tqdm

# Basic optimizations
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ['OMP_NUM_THREADS'] = str(os.cpu_count())

# Set random seeds
np.random.seed(42)
tf.random.set_seed(42)

# Constants
KIBA_MAX_DRUG_LEN = 100
KIBA_MAX_PROT_LEN = 1000
EMBEDDING_DIM = 128
KIBA_DATA_PATH = './kiba'
SPLIT_PATH = "/content/New Data/kiba_split.json"  # << load precomputed split

# Enable XLA for faster computation
try:
    tf.config.optimizer.set_jit(True)
except:
    pass

def concordance_index(y_true, y_pred):
    y_true = y_true.flatten().astype(np.float32)
    y_pred = y_pred.flatten().astype(np.float32)
    mask = ~(np.isnan(y_true) | np.isnan(y_pred))
    y_true = y_true[mask]
    y_pred = y_pred[mask]
    if len(y_true) < 2:
        return 0.0
    if len(y_true) > 10000:
        indices = np.random.choice(len(y_true), 10000, replace=False)
        y_true = y_true[indices]
        y_pred = y_pred[indices]
    n = len(y_true)
    indices = np.arange(n)
    i_indices, j_indices = np.meshgrid(indices, indices, indexing='ij')
    mask = i_indices < j_indices
    y_true_i = y_true[i_indices[mask]]
    y_true_j = y_true[j_indices[mask]]
    y_pred_i = y_pred[i_indices[mask]]
    y_pred_j = y_pred[j_indices[mask]]
    different_mask = y_true_i != y_true_j
    if np.sum(different_mask) == 0:
        return 0.0
    y_true_i = y_true_i[different_mask]
    y_true_j = y_true_j[different_mask]
    y_pred_i = y_pred_i[different_mask]
    y_pred_j = y_pred_j[different_mask]
    concordant = ((y_true_i > y_true_j) & (y_pred_i > y_pred_j)) | \
                 ((y_true_i < y_true_j) & (y_pred_i < y_pred_j))
    ties = (y_pred_i == y_pred_j)
    return (np.sum(concordant) + 0.5 * np.sum(ties)) / len(y_true_i)

def create_char_vocab(sequences_dict):
    char_set = set()
    for seq in tqdm(sequences_dict.values(), desc="Processing sequences", unit="seq"):
        char_set.update(seq)
    chars = sorted(list(char_set))
    char_to_int = {char: idx + 1 for idx, char in enumerate(chars)}
    return char_to_int

def encode_sequences_batch(sequences, char_vocab, max_length, desc="Encoding sequences"):
    encoded_sequences = []
    for sequence in tqdm(sequences, desc=desc, unit="seq"):
        encoded = [char_vocab.get(char, 0) for char in sequence]
        if len(encoded) < max_length:
            encoded += [0] * (max_length - len(encoded))
        else:
            encoded = encoded[:max_length]
        encoded_sequences.append(encoded)
    return np.array(encoded_sequences, dtype=np.int32)

class OptimizedKibaDataProcessor:
    """Enhanced data processor with detailed progress tracking."""

    def __init__(self, data_path='./kiba', max_drug_len=100, max_prot_len=1000):
        self.data_path = data_path
        self.max_drug_len = max_drug_len
        self.max_prot_len = max_prot_len
        self.drug_vocab = None
        self.prot_vocab = None

    def load_data(self):
        """Load data using precomputed split from SPLIT_PATH."""
        try:
            ligands_path = os.path.join(self.data_path, 'ligands_can.txt')
            proteins_path = os.path.join(self.data_path, 'proteins.txt')

            with open(ligands_path, 'r') as f:
                drugs_dict = json.load(f)
            with open(proteins_path, 'r') as f:
                proteins_dict = json.load(f)

            y_file_path = os.path.join(self.data_path, 'Y')
            if os.path.exists(y_file_path):
                try:
                    with open(y_file_path, 'rb') as f:
                        affinity_matrix = pickle.load(f)
                except:
                    with open(y_file_path, 'rb') as f:
                        affinity_matrix = pickle.load(f, encoding='latin1')
            else:
                raise FileNotFoundError(f"Y file not found at {y_file_path}")

            valid_indices = np.where(~np.isnan(affinity_matrix))
            total_valid_pairs = len(valid_indices[0])

            if not os.path.exists(SPLIT_PATH):
                raise FileNotFoundError(f"Split file not found at {SPLIT_PATH}")

            with open(SPLIT_PATH, "r") as f:
                split = json.load(f)
            train_indices = np.array(split["train_indices"], dtype=int)
            test_indices  = np.array(split["test_indices"], dtype=int)

            if "total_valid_pairs" in split and int(split["total_valid_pairs"]) != int(total_valid_pairs):
                print(f"[warn] total_valid_pairs in split ({split['total_valid_pairs']}) != current ({total_valid_pairs})")

            return drugs_dict, proteins_dict, affinity_matrix, train_indices, test_indices, valid_indices

        except Exception as e:
            print(f"[error] load_data failed: {e}")
            return None

    def process_data(self):
        """Process data with comprehensive progress tracking."""
        data = self.load_data()
        if data is None:
            return None

        drugs_dict, proteins_dict, affinity_matrix, train_indices, test_indices, valid_indices = data

        self.drug_vocab = create_char_vocab(drugs_dict)
        self.prot_vocab = create_char_vocab(proteins_dict)

        drug_ids = list(drugs_dict.keys())
        protein_ids = list(proteins_dict.keys())

        def create_dataset_optimized(indices, dataset_name):
            drug_sequences = []
            prot_sequences = []
            affinities = []

            chunk_size = 10000
            total_chunks = (len(indices) + chunk_size - 1) // chunk_size
            chunk_pbar = tqdm(total=total_chunks, desc=f"Processing {dataset_name} chunks", unit="chunk")

            for chunk_idx, i in enumerate(range(0, len(indices), chunk_size)):
                chunk_indices = indices[i:i + chunk_size]
                chunk_drugs = []
                chunk_prots = []
                chunk_affs = []

                sample_pbar = tqdm(
                    chunk_indices,
                    desc=f"Chunk {chunk_idx + 1}/{total_chunks}",
                    unit="sample",
                    leave=False
                )

                for idx in sample_pbar:
                    if idx < len(valid_indices[0]):
                        drug_idx = valid_indices[0][idx]
                        prot_idx = valid_indices[1][idx]

                        if drug_idx < len(drug_ids) and prot_idx < len(protein_ids):
                            drug_id = drug_ids[drug_idx]
                            prot_id = protein_ids[prot_idx]

                            chunk_drugs.append(drugs_dict[drug_id])
                            chunk_prots.append(proteins_dict[prot_id])
                            chunk_affs.append(affinity_matrix[drug_idx, prot_idx])

                sample_pbar.close()

                if chunk_drugs:
                    encoded_drugs = encode_sequences_batch(
                        chunk_drugs, self.drug_vocab, self.max_drug_len,
                        desc=f"Encoding drugs (chunk {chunk_idx + 1})"
                    )
                    encoded_prots = encode_sequences_batch(
                        chunk_prots, self.prot_vocab, self.max_prot_len,
                        desc=f"Encoding proteins (chunk {chunk_idx + 1})"
                    )

                    drug_sequences.append(encoded_drugs)
                    prot_sequences.append(encoded_prots)
                    affinities.extend(chunk_affs)

                chunk_pbar.update(1)

            chunk_pbar.close()

            if drug_sequences:
                drugs = np.concatenate(drug_sequences, axis=0)
                proteins = np.concatenate(prot_sequences, axis=0)
                affinities = np.array(affinities, dtype=np.float32)
            else:
                drugs = np.array([], dtype=np.int32).reshape(0, self.max_drug_len)
                proteins = np.array([], dtype=np.int32).reshape(0, self.max_prot_len)
                affinities = np.array([], dtype=np.float32)

            return drugs, proteins, affinities

        XD_train, XT_train, y_train = create_dataset_optimized(train_indices, "training")
        XD_test, XT_test, y_test = create_dataset_optimized(test_indices, "test")

        return ((XD_train, XT_train, y_train),
                (XD_test, XT_test, y_test),
                (len(self.drug_vocab) + 1, len(self.prot_vocab) + 1))

def build_fast_deepdta_model(drug_vocab_size, prot_vocab_size, max_drug_len, max_prot_len):
    EMBEDDING_DIM = 128
    DROPOUT_RATE = 0.1
    LEARNING_RATE = 0.001
    FILTER_NUM_1 = 32
    FILTER_NUM_2 = 64
    FILTER_NUM_3 = 96
    DRUG_FILTER_LENS = [4, 6, 8]
    PROT_FILTER_LENS = [4, 8, 12]
    FC_NEURONS_1 = 1024
    FC_NEURONS_2 = 1024
    FC_NEURONS_3 = 512

    drug_input = layers.Input(shape=(max_drug_len,), name='drug_input', dtype='int32')
    drug_embedding = layers.Embedding(
        input_dim=drug_vocab_size,
        output_dim=EMBEDDING_DIM,
        input_length=max_drug_len,
        name='drug_embedding'
    )(drug_input)
    drug_conv1 = layers.Conv1D(filters=FILTER_NUM_1, kernel_size=DRUG_FILTER_LENS[0],
                               activation='relu', name='drug_conv1')(drug_embedding)
    drug_conv2 = layers.Conv1D(filters=FILTER_NUM_2, kernel_size=DRUG_FILTER_LENS[1],
                               activation='relu', name='drug_conv2')(drug_conv1)
    drug_conv3 = layers.Conv1D(filters=FILTER_NUM_3, kernel_size=DRUG_FILTER_LENS[2],
                               activation='relu', name='drug_conv3')(drug_conv2)
    drug_pool = layers.GlobalMaxPooling1D(name='drug_global_max_pooling')(drug_conv3)

    prot_input = layers.Input(shape=(max_prot_len,), name='protein_input', dtype='int32')
    prot_embedding = layers.Embedding(
        input_dim=prot_vocab_size,
        output_dim=EMBEDDING_DIM,
        input_length=max_prot_len,
        name='protein_embedding'
    )(prot_input)
    prot_conv1 = layers.Conv1D(filters=FILTER_NUM_1, kernel_size=PROT_FILTER_LENS[0],
                               activation='relu', name='protein_conv1')(prot_embedding)
    prot_conv2 = layers.Conv1D(filters=FILTER_NUM_2, kernel_size=PROT_FILTER_LENS[1],
                               activation='relu', name='protein_conv2')(prot_conv1)
    prot_conv3 = layers.Conv1D(filters=FILTER_NUM_3, kernel_size=PROT_FILTER_LENS[2],
                               activation='relu', name='protein_conv3')(prot_conv2)
    prot_pool = layers.GlobalMaxPooling1D(name='protein_global_max_pooling')(prot_conv3)

    combined = layers.Concatenate(axis=1, name='concatenate_branches')([drug_pool, prot_pool])
    fc1 = layers.Dense(FC_NEURONS_1, activation='relu', name='fully_connected_1')(combined)
    fc1_dropout = layers.Dropout(DROPOUT_RATE, name='dropout_1')(fc1)
    fc2 = layers.Dense(FC_NEURONS_2, activation='relu', name='fully_connected_2')(fc1_dropout)
    fc2_dropout = layers.Dropout(DROPOUT_RATE, name='dropout_2')(fc2)
    fc3 = layers.Dense(FC_NEURONS_3, activation='relu', name='fully_connected_3')(fc2_dropout)
    output = layers.Dense(1, activation='linear', name='output')(fc3)

    model = Model(inputs=[drug_input, prot_input], outputs=output, name='DeepDTA')
    optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(optimizer=optimizer, loss='mean_squared_error',
                  metrics=['mean_squared_error'])
    return model

print("All functions and classes defined successfully!")
print("OptimizedKibaDataProcessor is now available!")
print("Ready to process data!")
# Out:
# All functions and classes defined successfully!
# OptimizedKibaDataProcessor is now available!
# Ready to process data!

# %%
#Section 2

import zipfile
import os

# Define the path to your zip file
zip_file_path = '/content/data.zip' # Replace with the actual path to your .zip file

# Define the directory where you want to extract the contents
# If the directory doesn't exist, it will be created.
extract_dir = '/content/' # You can change this to your desired extraction path

# Create the extraction directory if it doesn't exist
os.makedirs(extract_dir, exist_ok=True)

# Extract the zip file
try:
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print(f"Successfully extracted '{zip_file_path}' to '{extract_dir}'")
except FileNotFoundError:
    print(f"Error: The file '{zip_file_path}' was not found.")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_path}' is not a valid zip file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# Optional: List the contents of the extracted directory to verify
print("\nContents of the extracted directory:")
for item in os.listdir(extract_dir):
    print(os.path.join(extract_dir, item))
# Out:
# Successfully extracted '/content/data.zip' to '/content/'
#
# Contents of the extracted directory:
# /content/.config
# /content/data.zip
# /content/kiba
# /content/New Data
# /content/.ipynb_checkpoints
# /content/davis
# /content/sample_data

# %%
#Section 3

# Process the data
print("=== Starting Data Processing ===")

# Check if data path exists
if not os.path.exists(KIBA_DATA_PATH):
    print(f"Data path not found: {KIBA_DATA_PATH}")
    print("Please make sure you have uploaded and extracted the kiba folder.")
    print("Current directory contents:")
    for item in os.listdir('.'):
        print(f"  - {item}")
else:
    print(f"Data path found: {KIBA_DATA_PATH}")

    # Now OptimizedKibaDataProcessor should be available
    processor = OptimizedKibaDataProcessor(data_path=KIBA_DATA_PATH)

    processed_data = processor.process_data()
    if processed_data is None:
        print("Failed to process data. Please check your data files.")
    else:
        (XD_train, XT_train, y_train), (XD_test, XT_test, y_test), (drug_vocab_size, prot_vocab_size) = processed_data
        print("Data processing completed successfully!")
        print(f"Data shapes:")
        print(f"   XD_train: {XD_train.shape}, dtype: {XD_train.dtype}")
        print(f"   XT_train: {XT_train.shape}, dtype: {XT_train.dtype}")
        print(f"   y_train: {y_train.shape}, dtype: {y_train.dtype}")
        print(f"   XD_test: {XD_test.shape}, dtype: {XD_test.dtype}")
        print(f"   XT_test: {XT_test.shape}, dtype: {XT_test.dtype}")
        print(f"   y_test: {y_test.shape}, dtype: {y_test.dtype}")
# Out:
# === Starting Data Processing ===
# Data path found: ./kiba
# Processing sequences: 100%|██████████| 2111/2111 [00:00<00:00, 998328.53seq/s]
# Processing sequences: 100%|██████████| 229/229 [00:00<00:00, 86004.26seq/s]
# Processing training chunks:   0%|          | 0/10 [00:00<?, ?chunk/s]
# Chunk 1/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 230676.80seq/s]
#
# Encoding proteins (chunk 1):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 1):  25%|██▍       | 2492/10000 [00:00<00:00, 24912.96seq/s]
# Encoding proteins (chunk 1):  50%|████▉     | 4984/10000 [00:00<00:00, 22451.72seq/s]
# Encoding proteins (chunk 1):  72%|███████▏  | 7246/10000 [00:00<00:00, 22125.09seq/s]
# Encoding proteins (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 22326.11seq/s]
# Processing training chunks:  10%|█         | 1/10 [00:00<00:08,  1.02chunk/s]
# Chunk 2/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 238223.39seq/s]
#
# Encoding proteins (chunk 2):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 2):  25%|██▍       | 2454/10000 [00:00<00:00, 24537.57seq/s]
# Encoding proteins (chunk 2):  49%|████▉     | 4908/10000 [00:00<00:00, 22928.40seq/s]
# Encoding proteins (chunk 2):  72%|███████▏  | 7208/10000 [00:00<00:00, 22329.91seq/s]
# Encoding proteins (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 19333.20seq/s]
# Processing training chunks:  20%|██        | 2/10 [00:02<00:09,  1.21s/chunk]
# Chunk 3/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 3): 100%|██████████| 10000/10000 [00:00<00:00, 136507.12seq/s]
#
# Encoding proteins (chunk 3):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 3):  14%|█▍        | 1409/10000 [00:00<00:00, 14085.14seq/s]
# Encoding proteins (chunk 3):  28%|██▊       | 2818/10000 [00:00<00:00, 13256.29seq/s]
# Encoding proteins (chunk 3):  41%|████▏     | 4147/10000 [00:00<00:00, 12945.01seq/s]
# Encoding proteins (chunk 3):  55%|█████▍    | 5466/10000 [00:00<00:00, 13037.38seq/s]
# Encoding proteins (chunk 3):  68%|██████▊   | 6772/10000 [00:00<00:00, 11766.95seq/s]
# Encoding proteins (chunk 3):  80%|███████▉  | 7967/10000 [00:00<00:00, 11742.51seq/s]
# Encoding proteins (chunk 3): 100%|██████████| 10000/10000 [00:00<00:00, 12272.08seq/s]
# Processing training chunks:  30%|███       | 3/10 [00:04<00:10,  1.44s/chunk]
# Chunk 4/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 4): 100%|██████████| 10000/10000 [00:00<00:00, 234091.11seq/s]
#
# Encoding proteins (chunk 4):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 4):  23%|██▎       | 2342/10000 [00:00<00:00, 23409.42seq/s]
# Encoding proteins (chunk 4):  47%|████▋     | 4683/10000 [00:00<00:00, 21243.31seq/s]
# Encoding proteins (chunk 4):  69%|██████▉   | 6921/10000 [00:00<00:00, 21732.63seq/s]
# Encoding proteins (chunk 4): 100%|██████████| 10000/10000 [00:00<00:00, 21819.23seq/s]
# Processing training chunks:  40%|████      | 4/10 [00:05<00:07,  1.28s/chunk]
# Chunk 5/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 5): 100%|██████████| 10000/10000 [00:00<00:00, 195758.59seq/s]
#
# Encoding proteins (chunk 5):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 5):  24%|██▍       | 2401/10000 [00:00<00:00, 24007.33seq/s]
# Encoding proteins (chunk 5):  48%|████▊     | 4825/10000 [00:00<00:00, 24136.35seq/s]
# Encoding proteins (chunk 5):  72%|███████▏  | 7239/10000 [00:00<00:00, 23624.54seq/s]
# Encoding proteins (chunk 5): 100%|██████████| 10000/10000 [00:00<00:00, 21621.18seq/s]
# Processing training chunks:  50%|█████     | 5/10 [00:06<00:05,  1.20s/chunk]
# Chunk 6/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 6): 100%|██████████| 10000/10000 [00:00<00:00, 228314.87seq/s]
#
# Encoding proteins (chunk 6):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 6):  25%|██▌       | 2506/10000 [00:00<00:00, 25040.20seq/s]
# Encoding proteins (chunk 6):  50%|█████     | 5011/10000 [00:00<00:00, 23936.26seq/s]
# Encoding proteins (chunk 6):  74%|███████▍  | 7408/10000 [00:00<00:00, 21667.60seq/s]
# Encoding proteins (chunk 6): 100%|██████████| 10000/10000 [00:00<00:00, 22073.81seq/s]
# Processing training chunks:  60%|██████    | 6/10 [00:07<00:04,  1.13s/chunk]
# Chunk 7/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 7): 100%|██████████| 10000/10000 [00:00<00:00, 240053.11seq/s]
#
# Encoding proteins (chunk 7):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 7):  26%|██▌       | 2554/10000 [00:00<00:00, 25530.16seq/s]
# Encoding proteins (chunk 7):  51%|█████     | 5108/10000 [00:00<00:00, 22865.94seq/s]
# Encoding proteins (chunk 7):  74%|███████▍  | 7413/10000 [00:00<00:00, 22922.23seq/s]
# Encoding proteins (chunk 7): 100%|██████████| 10000/10000 [00:00<00:00, 22355.40seq/s]
# Processing training chunks:  70%|███████   | 7/10 [00:08<00:03,  1.09s/chunk]
# Chunk 8/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 8): 100%|██████████| 10000/10000 [00:00<00:00, 235604.61seq/s]
#
# Encoding proteins (chunk 8):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 8):   8%|▊         | 755/10000 [00:00<00:02, 3912.22seq/s]
# Encoding proteins (chunk 8):  31%|███       | 3075/10000 [00:00<00:00, 12115.73seq/s]
# Encoding proteins (chunk 8):  55%|█████▍    | 5496/10000 [00:00<00:00, 16685.46seq/s]
# Encoding proteins (chunk 8):  78%|███████▊  | 7783/10000 [00:00<00:00, 18852.89seq/s]
# Encoding proteins (chunk 8): 100%|██████████| 10000/10000 [00:00<00:00, 15890.98seq/s]
# Processing training chunks:  80%|████████  | 8/10 [00:09<00:02,  1.11s/chunk]
# Chunk 9/10:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 9): 100%|██████████| 10000/10000 [00:00<00:00, 239446.01seq/s]
#
# Encoding proteins (chunk 9):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 9):  24%|██▍       | 2444/10000 [00:00<00:00, 24434.37seq/s]
# Encoding proteins (chunk 9):  49%|████▉     | 4888/10000 [00:00<00:00, 24401.87seq/s]
# Encoding proteins (chunk 9):  73%|███████▎  | 7329/10000 [00:00<00:00, 21417.41seq/s]
# Encoding proteins (chunk 9): 100%|██████████| 10000/10000 [00:00<00:00, 21794.79seq/s]
# Processing training chunks:  90%|█████████ | 9/10 [00:10<00:01,  1.08s/chunk]
# Chunk 10/10:   0%|          | 0/4603 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 10): 100%|██████████| 4603/4603 [00:00<00:00, 207085.58seq/s]
#
# Encoding proteins (chunk 10):   0%|          | 0/4603 [00:00<?, ?seq/s]
# Encoding proteins (chunk 10): 100%|██████████| 4603/4603 [00:00<00:00, 24681.05seq/s]
# Processing training chunks: 100%|██████████| 10/10 [00:10<00:00,  1.08s/chunk]
# Processing test chunks:   0%|          | 0/3 [00:00<?, ?chunk/s]
# Chunk 1/3:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 236020.91seq/s]
#
# Encoding proteins (chunk 1):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 1):  22%|██▏       | 2191/10000 [00:00<00:00, 21905.01seq/s]
# Encoding proteins (chunk 1):  44%|████▍     | 4382/10000 [00:00<00:00, 21431.13seq/s]
# Encoding proteins (chunk 1):  66%|██████▌   | 6602/10000 [00:00<00:00, 21776.37seq/s]
# Encoding proteins (chunk 1): 100%|██████████| 10000/10000 [00:00<00:00, 21664.45seq/s]
# Processing test chunks:  33%|███▎      | 1/3 [00:01<00:02,  1.03s/chunk]
# Chunk 2/3:   0%|          | 0/10000 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 212587.25seq/s]
#
# Encoding proteins (chunk 2):   0%|          | 0/10000 [00:00<?, ?seq/s]
# Encoding proteins (chunk 2):  26%|██▌       | 2591/10000 [00:00<00:00, 25905.33seq/s]
# Encoding proteins (chunk 2):  52%|█████▏    | 5182/10000 [00:00<00:00, 23889.14seq/s]
# Encoding proteins (chunk 2):  76%|███████▌  | 7582/10000 [00:00<00:00, 22974.08seq/s]
# Encoding proteins (chunk 2): 100%|██████████| 10000/10000 [00:00<00:00, 21314.65seq/s]
# Processing test chunks:  67%|██████▋   | 2/3 [00:02<00:01,  1.03s/chunk]
# Chunk 3/3:   0%|          | 0/3651 [00:00<?, ?sample/s]
#
# Encoding drugs (chunk 3): 100%|██████████| 3651/3651 [00:00<00:00, 229896.47seq/s]
#
# Encoding proteins (chunk 3):   0%|          | 0/3651 [00:00<?, ?seq/s]
# Encoding proteins (chunk 3): 100%|██████████| 3651/3651 [00:00<00:00, 21177.93seq/s]
# Processing test chunks: 100%|██████████| 3/3 [00:02<00:00,  1.23chunk/s]
# Data processing completed successfully!
# Data shapes:
#    XD_train: (94603, 100), dtype: int32
#    XT_train: (94603, 1000), dtype: int32
#    y_train: (94603,), dtype: float32
#    XD_test: (23651, 100), dtype: int32
#    XT_test: (23651, 1000), dtype: int32
#    y_test: (23651,), dtype: float32

# %%
#Section 4

# CORRECTED CONFIGURATION
REDUCE_DATASET = True
DATASET_FRACTION = 1
EPOCHS = 100
BATCH_SIZE = 256  # REDUCED for better stability
VALIDATION_SPLIT = 0.1

print("CORRECTED CONFIGURATION:")
print("=" * 50)
print(f"Batch size: {BATCH_SIZE}")
print(f"Epochs: {EPOCHS}")

# FIXED: Proper dataset reduction
if 'XD_train' in locals() and len(XD_train) > 1000:  # Only if we have full data

    # Use the ORIGINAL full dataset, not the already reduced one
    print(f"Using original dataset: {len(XD_train):,} training samples")

    # Calculate correct sample sizes
    n_train = int(len(XD_train) * DATASET_FRACTION)
    n_test = int(len(XD_test) * DATASET_FRACTION)

    print(f"Target training samples: {n_train:,}")
    print(f"Target test samples: {n_test:,}")

    # Randomly sample subset
    np.random.seed(42)  # For reproducibility
    train_indices = np.random.choice(len(XD_train), n_train, replace=False)
    test_indices = np.random.choice(len(XD_test), n_test, replace=False)

    XD_train = XD_train[train_indices]
    XT_train = XT_train[train_indices]
    y_train = y_train[train_indices]

    XD_test = XD_test[test_indices]
    XT_test = XT_test[test_indices]
    y_test = y_test[test_indices]

    # Calculate batches per epoch
    batches_per_epoch = len(XD_train) // BATCH_SIZE

    print(f"CORRECTED DATASET:")
    print(f"   Training: {len(XD_train):,} samples")
    print(f"   Test: {len(XD_test):,} samples")
    print(f"   Batches per epoch: {batches_per_epoch}")
    print(f"   Much more stable training expected!")

    # Use corrected datasets
    XD_train = XD_train
    XT_train = XT_train
    y_train = y_train
    XD_test = XD_test
    XT_test = XT_test
    y_test = y_test

    print("Ready for corrected training!")

elif 'XD_train' in locals():
    print(f"Current dataset already reduced: {len(XD_train):,} samples")
    print("Please restart and run data processing again for full dataset")

    # Still apply batch size fix for current data
    batches_per_epoch = len(XD_train) // BATCH_SIZE
    print(f"Batches per epoch with current data: {batches_per_epoch}")

else:
    print("Cannot apply optimizations - data not loaded yet!")
# Out:
# CORRECTED CONFIGURATION:
# ==================================================
# Batch size: 256
# Epochs: 100
# Using original dataset: 94,603 training samples
# Target training samples: 94,603
# Target test samples: 23,651
# CORRECTED DATASET:
#    Training: 94,603 samples
#    Test: 23,651 samples
#    Batches per epoch: 369
#    Much more stable training expected!
# Ready for corrected training!

# %%
#Section 5

# Build the model (only if data processing was successful)
if 'XD_train' in locals() and 'drug_vocab_size' in locals():
    print("\n=== Building Optimized Model ===")

    # Build the fast model
    fast_model = build_fast_deepdta_model(
        drug_vocab_size=drug_vocab_size,
        prot_vocab_size=prot_vocab_size,
        max_drug_len=processor.max_drug_len,
        max_prot_len=processor.max_prot_len
    )

    print("\n=== Model Summary ===")
    fast_model.summary()
    print("Model built successfully!")
else:
    print("Cannot build model - data processing failed or incomplete")
# Out:
# === Building Optimized Model ===
#
# === Model Summary ===
# Model: "DeepDTA"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ drug_input          │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_input       │ (None, 1000)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_embedding      │ (None, 100, 128)  │      3,840 │ drug_input[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_embedding   │ (None, 1000, 128) │      2,688 │ protein_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_conv1 (Conv1D) │ (None, 97, 32)    │     16,416 │ drug_embedding[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_conv1       │ (None, 997, 32)   │     16,416 │ protein_embeddin… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_conv2 (Conv1D) │ (None, 92, 64)    │     12,352 │ drug_conv1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_conv2       │ (None, 990, 64)   │     16,448 │ protein_conv1[0]… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_conv3 (Conv1D) │ (None, 85, 96)    │     49,248 │ drug_conv2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_conv3       │ (None, 979, 96)   │     73,824 │ protein_conv2[0]… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ drug_global_max_po… │ (None, 96)        │          0 │ drug_conv3[0][0]  │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ protein_global_max… │ (None, 96)        │          0 │ protein_conv3[0]… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_branch… │ (None, 192)       │          0 │ drug_global_max_… │
# │ (Concatenate)       │                   │            │ protein_global_m… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_1   │ (None, 1024)      │    197,632 │ concatenate_bran… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ fully_connected_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_2   │ (None, 1024)      │  1,049,600 │ dropout_1[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1024)      │          0 │ fully_connected_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fully_connected_3   │ (None, 512)       │    524,800 │ dropout_2[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │        513 │ fully_connected_… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,963,777 (7.49 MB)
#  Trainable params: 1,963,777 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Model built successfully!

# %%
#Section 6

# OPTIMIZED TRAINING
if 'fast_model' in locals():
    print("STARTING OPTIMIZED TRAINING ...")
    print("=" * 55)

    # Training configuration summary
    print(f"Configuration Summary:")
    print(f"   Batch size: {BATCH_SIZE}")
    print(f"   Epochs: {EPOCHS}")
    print(f"   Training samples: {len(XD_train):,}")
    print(f"   Test samples: {len(XD_test):,}")
    print(f"   Batches per epoch: {len(XD_train) // BATCH_SIZE}")

    # Optimized callbacks for the full dataset
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=15,  # More patience for larger dataset
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=7,   # More patience for larger dataset
            min_lr=1e-6,
            verbose=1
        )
    ]

    print(f"\nStarting training...")
    print(f"Expected CI: 0.72-0.78 (significant improvement over 50%)")
    print(f"Expected total time: 1-3 minutes")
    print("=" * 55)

    import time
    start_time = time.time()

    # Train the model
    history = fast_model.fit(
        x=[XD_train, XT_train],
        y=y_train,
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        validation_split=VALIDATION_SPLIT,
        callbacks=callbacks,
        verbose=1
    )

    end_time = time.time()
    training_time = end_time - start_time

    print(f"\nTRAINING COMPLETED!")
    print("=" * 30)
    print(f"Total training time: {training_time/60:.1f} minutes")
    print(f"Average per epoch: {training_time/len(history.history['loss']):.1f} seconds")
    print(f"Best validation loss: {min(history.history['val_loss']):.4f}")
    print(f"Final training loss: {history.history['loss'][-1]:.4f}")
    print(f"Total epochs completed: {len(history.history['loss'])}")

else:
    print("Cannot start training - model not built")
# Out:
# STARTING OPTIMIZED TRAINING ...
# =======================================================
# Configuration Summary:
#    Batch size: 256
#    Epochs: 100
#    Training samples: 94,603
#    Test samples: 23,651
#    Batches per epoch: 369
#
# Starting training...
# Expected CI: 0.72-0.78 (significant improvement over 50%)
# Expected total time: 1-3 minutes
# =======================================================
# Epoch 1/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 42s 125ms/step - loss: 8.4262 - mean_squared_error: 8.4262 - val_loss: 0.4923 - val_mean_squared_error: 0.4923 - learning_rate: 0.0010
# Epoch 2/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 74s 102ms/step - loss: 0.6302 - mean_squared_error: 0.6302 - val_loss: 0.4344 - val_mean_squared_error: 0.4344 - learning_rate: 0.0010
# Epoch 3/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.5677 - mean_squared_error: 0.5677 - val_loss: 0.4049 - val_mean_squared_error: 0.4049 - learning_rate: 0.0010
# Epoch 4/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.5397 - mean_squared_error: 0.5397 - val_loss: 0.3898 - val_mean_squared_error: 0.3898 - learning_rate: 0.0010
# Epoch 5/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.5179 - mean_squared_error: 0.5179 - val_loss: 0.3943 - val_mean_squared_error: 0.3943 - learning_rate: 0.0010
# Epoch 6/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.5129 - mean_squared_error: 0.5129 - val_loss: 0.3791 - val_mean_squared_error: 0.3791 - learning_rate: 0.0010
# Epoch 7/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.5030 - mean_squared_error: 0.5030 - val_loss: 0.3917 - val_mean_squared_error: 0.3917 - learning_rate: 0.0010
# Epoch 8/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.4911 - mean_squared_error: 0.4911 - val_loss: 0.4992 - val_mean_squared_error: 0.4992 - learning_rate: 0.0010
# Epoch 9/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.4777 - mean_squared_error: 0.4777 - val_loss: 0.4672 - val_mean_squared_error: 0.4672 - learning_rate: 0.0010
# Epoch 10/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.4847 - mean_squared_error: 0.4847 - val_loss: 0.4015 - val_mean_squared_error: 0.4015 - learning_rate: 0.0010
# Epoch 11/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.4360 - mean_squared_error: 0.4360 - val_loss: 0.4654 - val_mean_squared_error: 0.4654 - learning_rate: 0.0010
# Epoch 12/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.4114 - mean_squared_error: 0.4114 - val_loss: 0.3219 - val_mean_squared_error: 0.3219 - learning_rate: 0.0010
# Epoch 13/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.3859 - mean_squared_error: 0.3859 - val_loss: 0.3096 - val_mean_squared_error: 0.3096 - learning_rate: 0.0010
# Epoch 14/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.3641 - mean_squared_error: 0.3641 - val_loss: 0.2970 - val_mean_squared_error: 0.2970 - learning_rate: 0.0010
# Epoch 15/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.3517 - mean_squared_error: 0.3517 - val_loss: 0.2947 - val_mean_squared_error: 0.2947 - learning_rate: 0.0010
# Epoch 16/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.3403 - mean_squared_error: 0.3403 - val_loss: 0.2843 - val_mean_squared_error: 0.2843 - learning_rate: 0.0010
# Epoch 17/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.3311 - mean_squared_error: 0.3311 - val_loss: 0.2920 - val_mean_squared_error: 0.2920 - learning_rate: 0.0010
# Epoch 18/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 0.3234 - mean_squared_error: 0.3234 - val_loss: 0.2677 - val_mean_squared_error: 0.2677 - learning_rate: 0.0010
# Epoch 19/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.3136 - mean_squared_error: 0.3136 - val_loss: 0.2574 - val_mean_squared_error: 0.2574 - learning_rate: 0.0010
# Epoch 20/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2964 - mean_squared_error: 0.2964 - val_loss: 0.2515 - val_mean_squared_error: 0.2515 - learning_rate: 0.0010
# Epoch 21/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2820 - mean_squared_error: 0.2820 - val_loss: 0.2479 - val_mean_squared_error: 0.2479 - learning_rate: 0.0010
# Epoch 22/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2686 - mean_squared_error: 0.2686 - val_loss: 0.2436 - val_mean_squared_error: 0.2436 - learning_rate: 0.0010
# Epoch 23/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2658 - mean_squared_error: 0.2658 - val_loss: 0.2356 - val_mean_squared_error: 0.2356 - learning_rate: 0.0010
# Epoch 24/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.2581 - mean_squared_error: 0.2581 - val_loss: 0.2281 - val_mean_squared_error: 0.2281 - learning_rate: 0.0010
# Epoch 25/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2482 - mean_squared_error: 0.2482 - val_loss: 0.2366 - val_mean_squared_error: 0.2366 - learning_rate: 0.0010
# Epoch 26/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2462 - mean_squared_error: 0.2462 - val_loss: 0.2277 - val_mean_squared_error: 0.2277 - learning_rate: 0.0010
# Epoch 27/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.2324 - mean_squared_error: 0.2324 - val_loss: 0.2314 - val_mean_squared_error: 0.2314 - learning_rate: 0.0010
# Epoch 28/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2230 - mean_squared_error: 0.2230 - val_loss: 0.2228 - val_mean_squared_error: 0.2228 - learning_rate: 0.0010
# Epoch 29/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.2143 - mean_squared_error: 0.2143 - val_loss: 0.2479 - val_mean_squared_error: 0.2479 - learning_rate: 0.0010
# Epoch 30/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2127 - mean_squared_error: 0.2127 - val_loss: 0.2149 - val_mean_squared_error: 0.2149 - learning_rate: 0.0010
# Epoch 31/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.2067 - mean_squared_error: 0.2067 - val_loss: 0.2237 - val_mean_squared_error: 0.2237 - learning_rate: 0.0010
# Epoch 32/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.1981 - mean_squared_error: 0.1981 - val_loss: 0.2160 - val_mean_squared_error: 0.2160 - learning_rate: 0.0010
# Epoch 33/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1937 - mean_squared_error: 0.1937 - val_loss: 0.2285 - val_mean_squared_error: 0.2285 - learning_rate: 0.0010
# Epoch 34/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1871 - mean_squared_error: 0.1871 - val_loss: 0.2106 - val_mean_squared_error: 0.2106 - learning_rate: 0.0010
# Epoch 35/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1763 - mean_squared_error: 0.1763 - val_loss: 0.2059 - val_mean_squared_error: 0.2059 - learning_rate: 0.0010
# Epoch 36/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1737 - mean_squared_error: 0.1737 - val_loss: 0.2087 - val_mean_squared_error: 0.2087 - learning_rate: 0.0010
# Epoch 37/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1701 - mean_squared_error: 0.1701 - val_loss: 0.2106 - val_mean_squared_error: 0.2106 - learning_rate: 0.0010
# Epoch 38/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1643 - mean_squared_error: 0.1643 - val_loss: 0.2168 - val_mean_squared_error: 0.2168 - learning_rate: 0.0010
# Epoch 39/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 0.1562 - mean_squared_error: 0.1562 - val_loss: 0.2007 - val_mean_squared_error: 0.2007 - learning_rate: 0.0010
# Epoch 40/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1518 - mean_squared_error: 0.1518 - val_loss: 0.2108 - val_mean_squared_error: 0.2108 - learning_rate: 0.0010
# Epoch 41/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1530 - mean_squared_error: 0.1530 - val_loss: 0.2211 - val_mean_squared_error: 0.2211 - learning_rate: 0.0010
# Epoch 42/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.1664 - mean_squared_error: 0.1664 - val_loss: 0.2199 - val_mean_squared_error: 0.2199 - learning_rate: 0.0010
# Epoch 43/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1466 - mean_squared_error: 0.1466 - val_loss: 0.1988 - val_mean_squared_error: 0.1988 - learning_rate: 0.0010
# Epoch 44/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1395 - mean_squared_error: 0.1395 - val_loss: 0.1998 - val_mean_squared_error: 0.1998 - learning_rate: 0.0010
# Epoch 45/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.1296 - mean_squared_error: 0.1296 - val_loss: 0.2056 - val_mean_squared_error: 0.2056 - learning_rate: 0.0010
# Epoch 46/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.1232 - mean_squared_error: 0.1232 - val_loss: 0.1959 - val_mean_squared_error: 0.1959 - learning_rate: 0.0010
# Epoch 47/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1195 - mean_squared_error: 0.1195 - val_loss: 0.1972 - val_mean_squared_error: 0.1972 - learning_rate: 0.0010
# Epoch 48/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.1122 - mean_squared_error: 0.1122 - val_loss: 0.1916 - val_mean_squared_error: 0.1916 - learning_rate: 0.0010
# Epoch 49/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1092 - mean_squared_error: 0.1092 - val_loss: 0.2064 - val_mean_squared_error: 0.2064 - learning_rate: 0.0010
# Epoch 50/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1166 - mean_squared_error: 0.1166 - val_loss: 0.1964 - val_mean_squared_error: 0.1964 - learning_rate: 0.0010
# Epoch 51/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 0.1114 - mean_squared_error: 0.1114 - val_loss: 0.2004 - val_mean_squared_error: 0.2004 - learning_rate: 0.0010
# Epoch 52/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.1054 - mean_squared_error: 0.1054 - val_loss: 0.1993 - val_mean_squared_error: 0.1993 - learning_rate: 0.0010
# Epoch 53/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1072 - mean_squared_error: 0.1072 - val_loss: 0.2043 - val_mean_squared_error: 0.2043 - learning_rate: 0.0010
# Epoch 54/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1113 - mean_squared_error: 0.1113 - val_loss: 0.1890 - val_mean_squared_error: 0.1890 - learning_rate: 0.0010
# Epoch 55/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.1020 - mean_squared_error: 0.1020 - val_loss: 0.1853 - val_mean_squared_error: 0.1853 - learning_rate: 0.0010
# Epoch 56/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0954 - mean_squared_error: 0.0954 - val_loss: 0.1909 - val_mean_squared_error: 0.1909 - learning_rate: 0.0010
# Epoch 57/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0920 - mean_squared_error: 0.0920 - val_loss: 0.2005 - val_mean_squared_error: 0.2005 - learning_rate: 0.0010
# Epoch 58/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0884 - mean_squared_error: 0.0884 - val_loss: 0.1915 - val_mean_squared_error: 0.1915 - learning_rate: 0.0010
# Epoch 59/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0895 - mean_squared_error: 0.0895 - val_loss: 0.1973 - val_mean_squared_error: 0.1973 - learning_rate: 0.0010
# Epoch 60/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0857 - mean_squared_error: 0.0857 - val_loss: 0.1934 - val_mean_squared_error: 0.1934 - learning_rate: 0.0010
# Epoch 61/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0884 - mean_squared_error: 0.0884 - val_loss: 0.2016 - val_mean_squared_error: 0.2016 - learning_rate: 0.0010
# Epoch 62/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0863 - mean_squared_error: 0.0863
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0863 - mean_squared_error: 0.0863 - val_loss: 0.1941 - val_mean_squared_error: 0.1941 - learning_rate: 0.0010
# Epoch 63/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0714 - mean_squared_error: 0.0714 - val_loss: 0.1841 - val_mean_squared_error: 0.1841 - learning_rate: 5.0000e-04
# Epoch 64/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0578 - mean_squared_error: 0.0578 - val_loss: 0.1812 - val_mean_squared_error: 0.1812 - learning_rate: 5.0000e-04
# Epoch 65/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0536 - mean_squared_error: 0.0536 - val_loss: 0.1789 - val_mean_squared_error: 0.1789 - learning_rate: 5.0000e-04
# Epoch 66/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0504 - mean_squared_error: 0.0504 - val_loss: 0.1785 - val_mean_squared_error: 0.1785 - learning_rate: 5.0000e-04
# Epoch 67/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0487 - mean_squared_error: 0.0487 - val_loss: 0.1778 - val_mean_squared_error: 0.1778 - learning_rate: 5.0000e-04
# Epoch 68/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0468 - mean_squared_error: 0.0468 - val_loss: 0.1758 - val_mean_squared_error: 0.1758 - learning_rate: 5.0000e-04
# Epoch 69/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.1840 - val_mean_squared_error: 0.1840 - learning_rate: 5.0000e-04
# Epoch 70/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0451 - mean_squared_error: 0.0451 - val_loss: 0.1859 - val_mean_squared_error: 0.1859 - learning_rate: 5.0000e-04
# Epoch 71/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.1785 - val_mean_squared_error: 0.1785 - learning_rate: 5.0000e-04
# Epoch 72/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0429 - mean_squared_error: 0.0429 - val_loss: 0.1779 - val_mean_squared_error: 0.1779 - learning_rate: 5.0000e-04
# Epoch 73/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.0426 - mean_squared_error: 0.0426 - val_loss: 0.1767 - val_mean_squared_error: 0.1767 - learning_rate: 5.0000e-04
# Epoch 74/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0413 - mean_squared_error: 0.0413 - val_loss: 0.1768 - val_mean_squared_error: 0.1768 - learning_rate: 5.0000e-04
# Epoch 75/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0414 - mean_squared_error: 0.0414 - val_loss: 0.1753 - val_mean_squared_error: 0.1753 - learning_rate: 5.0000e-04
# Epoch 76/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0415 - mean_squared_error: 0.0415 - val_loss: 0.1722 - val_mean_squared_error: 0.1722 - learning_rate: 5.0000e-04
# Epoch 77/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 99ms/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.1768 - val_mean_squared_error: 0.1768 - learning_rate: 5.0000e-04
# Epoch 78/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.1838 - val_mean_squared_error: 0.1838 - learning_rate: 5.0000e-04
# Epoch 79/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.1855 - val_mean_squared_error: 0.1855 - learning_rate: 5.0000e-04
# Epoch 80/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0396 - mean_squared_error: 0.0396 - val_loss: 0.1831 - val_mean_squared_error: 0.1831 - learning_rate: 5.0000e-04
# Epoch 81/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.1793 - val_mean_squared_error: 0.1793 - learning_rate: 5.0000e-04
# Epoch 82/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.1739 - val_mean_squared_error: 0.1739 - learning_rate: 5.0000e-04
# Epoch 83/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0383 - mean_squared_error: 0.0383
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.1735 - val_mean_squared_error: 0.1735 - learning_rate: 5.0000e-04
# Epoch 84/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0344 - mean_squared_error: 0.0344 - val_loss: 0.1691 - val_mean_squared_error: 0.1691 - learning_rate: 2.5000e-04
# Epoch 85/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.1695 - val_mean_squared_error: 0.1695 - learning_rate: 2.5000e-04
# Epoch 86/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.1681 - val_mean_squared_error: 0.1681 - learning_rate: 2.5000e-04
# Epoch 87/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.1681 - val_mean_squared_error: 0.1681 - learning_rate: 2.5000e-04
# Epoch 88/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.1695 - val_mean_squared_error: 0.1695 - learning_rate: 2.5000e-04
# Epoch 89/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.1686 - val_mean_squared_error: 0.1686 - learning_rate: 2.5000e-04
# Epoch 90/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.1684 - val_mean_squared_error: 0.1684 - learning_rate: 2.5000e-04
# Epoch 91/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.1683 - val_mean_squared_error: 0.1683 - learning_rate: 2.5000e-04
# Epoch 92/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.1683 - val_mean_squared_error: 0.1683 - learning_rate: 2.5000e-04
# Epoch 93/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.1691 - val_mean_squared_error: 0.1691 - learning_rate: 2.5000e-04
# Epoch 94/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.1657 - val_mean_squared_error: 0.1657 - learning_rate: 1.2500e-04
# Epoch 95/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.1644 - val_mean_squared_error: 0.1644 - learning_rate: 1.2500e-04
# Epoch 96/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.1633 - val_mean_squared_error: 0.1633 - learning_rate: 1.2500e-04
# Epoch 97/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.1643 - val_mean_squared_error: 0.1643 - learning_rate: 1.2500e-04
# Epoch 98/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.1643 - val_mean_squared_error: 0.1643 - learning_rate: 1.2500e-04
# Epoch 99/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 41s 100ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.1651 - val_mean_squared_error: 0.1651 - learning_rate: 1.2500e-04
# Epoch 100/100
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 33s 100ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.1642 - val_mean_squared_error: 0.1642 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 96.
#
# TRAINING COMPLETED!
# ==============================
# Total training time: 65.2 minutes
# Average per epoch: 39.1 seconds
# Best validation loss: 0.1633
# Final training loss: 0.0202
# Total epochs completed: 100

# %%
#Section 7

# EVALUATION
if 'history' in locals():
    print("EVALUATING RESULTS...")
    print("=" * 45)

    # Make predictions
    print("Making predictions on test set...")
    y_pred_test = fast_model.predict([XD_test, XT_test], batch_size=BATCH_SIZE, verbose=1)

    # Calculate metrics
    print("Computing metrics...")
    test_mse = mean_squared_error(y_test, y_pred_test)
    test_ci = concordance_index(y_test, y_pred_test)

    print(f"\n100% DATASET RESULTS:")
    print("=" * 30)
    print(f"Test MSE: {test_mse:.6f}")
    print(f"Test CI: {test_ci:.6f}")

    # Performance comparison across all datasets
    print(f"\nPERFORMANCE PROGRESSION:")
    print("-" * 35)
    print(f"   10% dataset: CI = 0.6552")
    print(f"   Full dataset: CI = {test_ci:.4f}")

    # Comparison with literature
    print(f"\nLiterature Comparison:")
    print("-" * 25)
    print(f"   Paper DeepDTA: 0.863")
    print(f"   Our 100% model: {test_ci:.3f}")
    print(f"   Performance ratio: {test_ci/0.863:.1%}")

    # Performance analysis
    if test_ci >= 0.72:
        print(f"\nEXCELLENT! CI ≥ 0.72 - Ready for full dataset!")
        print(f"Next step: Try Full dataset for CI ≈ 0.80+")
    elif test_ci >= 0.68:
        print(f"\nGOOD! CI ≥ 0.68 - Model scaling properly")
        print(f"Continue scaling to Full dataset")
    else:
        print(f"\nCI < 0.68 - May need model architecture improvements")

    # Additional metrics
    mae = np.mean(np.abs(y_test - y_pred_test.flatten()))
    rmse = np.sqrt(test_mse)
    r2 = 1 - np.var(y_test - y_pred_test.flatten()) / np.var(y_test)

    print(f"\nAdditional Metrics:")
    print("-" * 20)
    print(f"MAE: {mae:.6f}")
    print(f"RMSE: {rmse:.6f}")
    print(f"R² Score: {r2:.6f}")

    print("\n" + "="*45)
    print("Full DATASET EVALUATION COMPLETED!")
    print("="*45)

else:
    print("Cannot evaluate - training not completed")
# Out:
# EVALUATING RESULTS...
# =============================================
# Making predictions on test set...
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step
# Computing metrics...
#
# 100% DATASET RESULTS:
# ==============================
# Test MSE: 0.173376
# Test CI: 0.871213
#
# PERFORMANCE PROGRESSION:
# -----------------------------------
#    10% dataset: CI = 0.6552
#    Full dataset: CI = 0.8712
#
# Literature Comparison:
# -------------------------
#    Paper DeepDTA: 0.863
#    Our 100% model: 0.871
#    Performance ratio: 101.0%
#
# EXCELLENT! CI ≥ 0.72 - Ready for full dataset!
# Next step: Try Full dataset for CI ≈ 0.80+
#
# Additional Metrics:
# --------------------
# MAE: 0.233875
# RMSE: 0.416384
# R² Score: 0.750146
#
# =============================================
# Full DATASET EVALUATION COMPLETED!
# =============================================
